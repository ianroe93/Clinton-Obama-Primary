# %% [markdown]
# # ObamaStarter

# %% [markdown]
# In this notebook, we will be building a predictive model to forecast the results of primary races in which Obama and Clinton both took part in the 2008 primary. We will use linear regression and regularized linear regression to forecast future primary results. We will also be interpreting these models in order to generate potentially useful insights for either the Obama or Clinton campaign to increase their chances of becoming the Democratic presidential nominee.
#
# NOTE: This notebook has a number of steps which are primarily for expositional purposes which are not necessary when building a final model. You may find it useful to make a copy of this notebook (right click on the notebook and select duplicate) and then remove steps or text to make your analysis a little cleaner. This is not necessary, but it can be helpful when you are trying to build your own model.

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.impute import SimpleImputer
from sklearn.linear_model import Ridge, Lasso
from sklearn.model_selection import train_test_split, GridSearchCV
import statsmodels.formula.api as smf

from patsy import dmatrices, dmatrix, build_design_matrices

import math

# %%
# This sets some nicer defaults for plotting.
# This must be run in a separate cell from importing matplotlib due to a bug.
params = {'legend.fontsize': 'large',
          'figure.figsize': (11.0, 11.0),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'xx-large',
          'xtick.labelsize':'large',
          'ytick.labelsize':'large'}
mpl.rcParams.update(params)

# This makes it so that the pandas dataframes don't get truncated horizontally.
pd.options.display.max_columns = 200

# %% [markdown]
# ## Load and Inspect the Data

# %% [markdown]
# We will load in our data set. However, this data set includes both past data and data on future primaries. The past data includes the candidates performance in the primaries that have already been completed. The primaries that are yet to be completed do not have this data.
#
# NOTE: Unlike many other datasets that we have, the training and the testing set are combined. We will have to create two datasets, one for training and the other for testing, later.

# %%
elect_df = pd.read_csv("Obama.csv")

# %% [markdown]
# What are the columns of the dataset?

# %%
elect_df.columns
# Out:
# Index(['County', 'State', 'Region', 'FIPS', 'ElectionDate', 'ElectionType',
#        'TotalVote', 'Clinton', 'Obama', 'MalesPer100Females', 'AgeBelow35',
#        'Age35to65', 'Age65andAbove', 'White', 'Black', 'Asian',
#        'AmericanIndian', 'Hawaiian', 'Hispanic', 'HighSchool', 'Bachelors',
#        'Poverty', 'IncomeAbove75K', 'MedianIncome', 'AverageIncome',
#        'UnemployRate', 'ManfEmploy', 'SpeakingNonEnglish', 'Medicare',
#        'MedicareRate', 'SocialSecurity', 'SocialSecurityRate',
#        'RetiredWorkers', 'Disabilities', 'DisabilitiesRate', 'Homeowner',
#        'SameHouse1995and2000', 'Pop', 'PopDensity', 'LandArea', 'FarmArea'],
#       dtype='object')

# %% [markdown]
# How many rows and columns do we have?

# %%
elect_df.shape
# Out:
# (2868, 41)

# %%
elect_df.head()
# Out:
#       County State   Region   FIPS ElectionDate ElectionType  TotalVote  \
# 0      Adair    IA  Midwest  19001     1/3/2008     Caucuses       75.0
# 1      Adams    IA  Midwest  19003     1/3/2008     Caucuses       50.0
# 2  Allamakee    IA  Midwest  19005     1/3/2008     Caucuses       80.0
# 3  Appanoose    IA  Midwest  19007     1/3/2008     Caucuses       60.0
# 4    Audubon    IA  Midwest  19009     1/3/2008     Caucuses       48.0
#
#    Clinton  Obama  MalesPer100Females  AgeBelow35  Age35to65  Age65andAbove  \
# 0     22.0   24.0                96.7        37.7       40.3           21.9
# 1     18.0    7.0                96.8        37.1       40.8           22.1
# 2     25.0   33.0               104.5        41.5       40.8           17.7
# 3     17.0   10.0                94.0        42.0       39.2           18.9
# 4     16.0   17.0                94.7        37.4       40.2           22.5
#
#    White  Black  Asian  AmericanIndian  Hawaiian  Hispanic  HighSchool  \
# 0   99.2    0.1    0.5             NaN       0.0       0.8        87.8
# 1   99.2    NaN    0.2             0.5       0.0       0.6        84.5
# 2   99.0    0.2    0.2             0.3       0.0       6.9        81.4
# 3   98.5    0.7    0.4             0.1       0.0       1.1        81.4
# 4   99.3    0.2    0.2             0.1       0.0       0.6        82.5
#
#    Bachelors  Poverty  IncomeAbove75K  MedianIncome  AverageIncome  \
# 0       11.2      9.7             8.6       39568.0        29222.0
# 1       12.0     10.6             7.8       35296.0        27297.0
# 2       14.4     10.8            10.7       36822.0        25579.0
# 3       12.2     14.9             6.6       31764.0        23705.0
# 4       12.3      9.2             9.7       38941.0        31100.0
#
#    UnemployRate  ManfEmploy  SpeakingNonEnglish  Medicare  MedicareRate  \
# 0           3.2   12.916739                 2.0    1551.0       19735.0
# 1           4.6    6.964421                 1.6     978.0       22936.0
# 2           4.6   16.473466                 8.2    2838.0       19294.0
# 3           5.4   15.080881                 2.5    3072.0       22479.0
# 4           4.1    8.333333                 2.7    1472.0       22797.0
#
#    SocialSecurity  SocialSecurityRate  RetiredWorkers  Disabilities  \
# 0          1825.0             23222.0          1230.0          90.0
# 1          1110.0             26032.0           720.0          78.0
# 2          3270.0             22231.0          2245.0         186.0
# 3          3415.0             24989.0          2050.0         453.0
# 4          1740.0             26947.0          1150.0          79.0
#
#    DisabilitiesRate  Homeowner  SameHouse1995and2000    Pop  PopDensity  \
# 0            1145.0       75.0                  66.0   7714        13.5
# 1            1829.0       74.7                  65.4   4192         9.9
# 2            1265.0       76.4                  64.1  14796        23.1
# 3            3315.0       74.0                  60.2  13422        27.0
# 4            1223.0       79.2                  70.4   6278        14.2
#
#    LandArea  FarmArea
# 0     570.0     373.0
# 1     425.0     238.0
# 2     659.0     326.0
# 3     516.0     236.0
# 4     444.0     261.0

# %%
def summarize_dataframe(df):
    missing_values = pd.concat([pd.DataFrame(df.columns, columns=['Variable Name']), 
                      pd.DataFrame(df.dtypes.values.reshape([-1,1]), columns=['Data Type']),
                      pd.DataFrame(df.isnull().sum().values, columns=['Missing Values']), 
                      pd.DataFrame([df[name].nunique() for name in df.columns], columns=['Unique Values'])], 
                     axis=1).set_index('Variable Name')
    return pd.concat([missing_values, df.describe(include='all').transpose()], axis=1).fillna("")

# %% [markdown]
# What are the names of the variables in the data frame? How many values are missing? Use our self defined `summarize_dataframe` function to find out the number of NA's for each variable.

# %%
summarize_dataframe(elect_df)
# Out:
#                      Data Type  Missing Values  Unique Values   count unique  \
# County                  object               0           1691  2868.0   1691
# State                   object               0             46  2868.0     46
# Region                  object               0              4  2868.0      4
# FIPS                     int64               0           2868  2868.0
# ElectionDate            object               0             18  2868.0     18
# ElectionType            object               0              2  2868.0      2
# TotalVote              float64            1131           1490  1737.0
# Clinton                float64            1131           1338  1737.0
# Obama                  float64            1131           1314  1737.0
# MalesPer100Females     float64               0            391  2868.0
# AgeBelow35             float64               0            310  2868.0
# Age35to65              float64               0            215  2868.0
# Age65andAbove          float64               0            227  2868.0
# White                  float64               0            547  2868.0
# Black                  float64              80            489  2788.0
# Asian                  float64              94            104  2774.0
# AmericanIndian         float64              99            158  2769.0
# Hawaiian               float64               0             20  2868.0
# Hispanic               float64               0            387  2868.0
# HighSchool             float64               1            410  2867.0
# Bachelors              float64               1            369  2867.0
# Poverty                float64               1            277  2867.0
# IncomeAbove75K         float64               2            357  2866.0
# MedianIncome           float64               1           2740  2867.0
# AverageIncome          float64              30           2624  2838.0
# UnemployRate           float64               1            103  2867.0
# ManfEmploy             float64             293           2574  2575.0
# SpeakingNonEnglish     float64               1            390  2867.0
# Medicare               float64               1           2584  2867.0
# MedicareRate           float64               1           2629  2867.0
# SocialSecurity         float64               1           2020  2867.0
# SocialSecurityRate     float64               1           2653  2867.0
# RetiredWorkers         float64               1           1702  2867.0
# Disabilities           float64               8           1748  2860.0
# DisabilitiesRate       float64               8           2171  2860.0
# Homeowner              float64               2            374  2866.0
# SameHouse1995and2000   float64               1            374  2867.0
# Pop                      int64               0           2827  2868.0
# PopDensity             float64               0           1548  2868.0
# LandArea               float64               1           1362  2867.0
# FarmArea               float64              87            795  2781.0
#
#                              top  freq          mean            std       min  \
# County                Washington    30
# State                         TX   251
# Region                     South  1419
# FIPS                                    31029.039052   15411.398662    1001.0
# ElectionDate            2/5/2008  1128
# ElectionType             Primary  2558
# TotalVote                                 12863.7962   53071.884245      13.0
# Clinton                                  5973.738054   25402.029497       4.0
# Obama                                    6178.122625   27477.231157       4.0
# MalesPer100Females                         99.081729       9.276792      76.2
# AgeBelow35                                 45.657252       5.539505       4.5
# Age35to65                                  39.587448       3.414974      18.6
# Age65andAbove                              14.757671       3.879482       2.2
# White                                      86.762134      15.965025       6.7
# Black                                       9.900215      15.098619       0.1
# Asian                                        1.06496       2.285771       0.1
# AmericanIndian                               1.68931       6.418587       0.1
# Hawaiian                                    0.077057       0.667552       0.0
# Hispanic                                    7.349442      12.874248       0.1
# HighSchool                                 76.898151       8.852567      34.7
# Bachelors                                  16.453784       7.921446       4.9
# Poverty                                    13.945553        5.24943       2.6
# IncomeAbove75K                             14.023447       7.559124       1.5
# MedianIncome                            39107.335542   10262.621095   16868.0
# AverageIncome                           27280.887949    6731.846182    5148.0
# UnemployRate                                4.899198       1.625128       1.5
# ManfEmploy                                 10.656417        7.73343  0.202429
# SpeakingNonEnglish                          8.617021      11.273343       0.4
# Medicare                                13724.160098   37807.170641       7.0
# MedicareRate                            17088.155215     4947.33554      60.0
# SocialSecurity                          15616.140565   40316.047789      20.0
# SocialSecurityRate                      19938.812347    4756.541802    1518.0
# RetiredWorkers                           9868.735612   26369.776166      15.0
# Disabilities                             2381.356993   10565.058494       4.0
# DisabilitiesRate                         2693.441958    1904.872546     125.0
# Homeowner                                   73.88866       7.576884      19.6
# SameHouse1995and2000                       58.742379       7.423108      15.4
# Pop                                     99225.983264  319260.353417      60.0
# PopDensity                                265.177755    1787.612548       0.1
# LandArea                                 1003.504011    1371.588433       2.0
# FarmArea                                  293.651564      375.84185       1.0
#
#                            25%       50%        75%        max
# County
# State
# Region
# FIPS                   18102.5   30110.0    46123.5    56045.0
# ElectionDate
# ElectionType
# TotalVote                732.0    2330.0     6418.0  1413869.0
# Clinton                  329.0    1106.0     3200.0   771700.0
# Obama                    254.0     878.0     2749.0   743686.0
# MalesPer100Females        94.9      97.6      100.5      200.9
# AgeBelow35                42.2      45.4       48.7       75.8
# Age35to65                 38.0      39.8       41.4       79.2
# Age65andAbove             12.2      14.4       17.0       33.7
# White                     81.9      93.7       97.5      100.0
# Black                      0.6       2.6     11.925       86.0
# Asian                      0.3       0.5        0.9       46.6
# AmericanIndian             0.2       0.4        0.8       91.8
# Hawaiian                   0.0       0.0        0.1       30.6
# Hispanic                   1.2       2.4        6.8       97.6
# HighSchool                70.6      78.7       83.6       97.0
# Bachelors                 11.1      14.3       19.3       63.7
# Poverty                   10.1      13.2       16.9       39.4
# IncomeAbove75K             9.2      11.9       16.4       57.3
# MedianIncome           32314.0   37272.0    43430.5    98245.0
# AverageIncome          23250.0   26222.0   29840.25    93377.0
# UnemployRate               3.8       4.7        5.7       15.3
# ManfEmploy            4.719391  8.950863  14.961274  57.229045
# SpeakingNonEnglish         3.0       4.6        8.6       92.1
# Medicare                2162.5    4514.0    10613.0  1059297.0
# MedicareRate           14108.5   16863.0    19853.5    60845.0
# SocialSecurity          2547.5    5360.0    12845.0  1047590.0
# SocialSecurityRate     16827.0   20040.0    23032.0    41943.0
# RetiredWorkers          1490.0    3095.0     7722.5   681035.0
# Disabilities            274.75     698.5    1671.25   400125.0
# DisabilitiesRate       1380.25    2192.5     3436.0    20185.0
# Homeowner                 70.5      75.2       78.9       89.6
# SameHouse1995and2000      54.3      59.4       64.0       90.5
# Pop                   12334.75   26967.5    68372.5  9948081.0
# PopDensity                19.8     47.25    118.025    70190.8
# LandArea                 434.0     626.0      950.0    20105.0
# FarmArea                  84.0     182.0      348.0     4595.0

# %% [markdown]
# We can see that we have some missing data. The missing data falls into two categories. First, we are missing data on `TotatVote`, `Clinton`, and `Obama`. These values are intended to be missing. They are data that we do not have yet, and this is what we will be trying to forecast. Often times, you will have two separate data sets, one that is intended for training that has all of the columns of data filled in and another for testing that is missing the prediction data. In this case, those two datasets are combined into one `.csv` file.
#
# Let's deal with this combined data first. We will manually separate out the training and the testing sets.

# %% [markdown]
# ## Creating Training and Testing Sets

# %% [markdown]
# We will create two separate data sets from the data in `elect_df`. We will create a _training_ data set and a _testing_ data set. The training data set will consist of elections that have already happened; the testing of those which are yet to come. In order to do this split, we need to be able to operate on _dates_.
#
# The below code converts the `ElectionDate` column from just an arbitrary string (in the view of pandas) to something that means dates ordered in time.

# %%
elect_df["ElectionDate"] = pd.to_datetime(elect_df["ElectionDate"])

# %% [markdown]
# Once we have this, we can take all of the data before February 19, 2008 as our training set, and all of the data after that point as our testing set.

# %%
elect_df_train = elect_df[elect_df["ElectionDate"] < pd.to_datetime("2/19/2008")].copy()

# %%
elect_df_test = elect_df[elect_df["ElectionDate"] >= pd.to_datetime("2/19/2008")].copy()

# %% [markdown]
# Note that above we did something a little strange. We called `.copy()` on the pandas dataframe. Sometimes when we are creating new dataframes from existing dataframes, we can end up "linking" the two dataframes instead of creating a new dataframe. This can cause some weird issues. Specifically, we can change something in one dataframe, and it will actually change it in the other dataframe because in the background they are the same dataframe.
#
# In order to avoid this, we are explicitly copying the dataframe. This tells python that we do not want these dataframes linked in the background. This often is not strictly necessary, but if you do not do this, it can lead to weird problems later on.

# %% [markdown]
# Now, we will create some possible dependent variables (things we might like to predict in a regression using the demographic information). These variables directly become a part of our data set `elect_df_train` dataframe.

# %%
elect_df_train["Obama_margin"] = elect_df_train["Obama"] - elect_df_train["Clinton"]
elect_df_train["Obama_margin_percent"] = elect_df_train["Obama_margin"] / elect_df_train["TotalVote"]
elect_df_train["Obama_wins"] = elect_df_train["Obama_margin"] > 0

# %% [markdown]
# Let's take a look and see that these variables are part of our dataframe now. You can also see that the "Data Type" of `ElectionDate` has changed. It is now a `datetime64[ns]` object because we told pandas that it is a date.

# %%
summarize_dataframe(elect_df_train)
# Out:
#                            Data Type  Missing Values  Unique Values   count  \
# County                        object               0           1138  1737.0
# State                         object               0             30  1737.0
# Region                        object               0              4  1737.0
# FIPS                           int64               0           1737  1737.0
# ElectionDate          datetime64[ns]               0              9  1737.0
# ElectionType                  object               0              2  1737.0
# TotalVote                    float64               0           1490  1737.0
# Clinton                      float64               0           1338  1737.0
# Obama                        float64               0           1314  1737.0
# MalesPer100Females           float64               0            344  1737.0
# AgeBelow35                   float64               0            274  1737.0
# Age35to65                    float64               0            195  1737.0
# Age65andAbove                float64               0            209  1737.0
# White                        float64               0            469  1737.0
# Black                        float64              42            429  1695.0
# Asian                        float64              42             97  1695.0
# AmericanIndian               float64              56            125  1681.0
# Hawaiian                     float64               0             13  1737.0
# Hispanic                     float64               0            281  1737.0
# HighSchool                   float64               1            360  1736.0
# Bachelors                    float64               1            342  1736.0
# Poverty                      float64               0            236  1737.0
# IncomeAbove75K               float64               1            328  1736.0
# MedianIncome                 float64               0           1688  1737.0
# AverageIncome                float64              29           1619  1708.0
# UnemployRate                 float64               0             92  1737.0
# ManfEmploy                   float64             171           1566  1566.0
# SpeakingNonEnglish           float64               1            296  1736.0
# Medicare                     float64               1           1628  1736.0
# MedicareRate                 float64               1           1651  1736.0
# SocialSecurity               float64               0           1394  1737.0
# SocialSecurityRate           float64               0           1664  1737.0
# RetiredWorkers               float64               0           1222  1737.0
# Disabilities                 float64               4           1260  1733.0
# DisabilitiesRate             float64               4           1449  1733.0
# Homeowner                    float64               1            350  1736.0
# SameHouse1995and2000         float64               1            345  1736.0
# Pop                            int64               0           1719  1737.0
# PopDensity                   float64               0           1141  1737.0
# LandArea                     float64               1           1018  1736.0
# FarmArea                     float64              78            603  1659.0
# Obama_margin                 float64               0           1267  1737.0
# Obama_margin_percent         float64               0           1701  1737.0
# Obama_wins                      bool               0              2  1737.0
#
#                      unique         top  freq                           mean  \
# County                 1138  Washington    19
# State                    30          GA   159
# Region                    4       South   811
# FIPS                                                            25907.716753
# ElectionDate                                   2008-02-03 09:22:54.093264128
# ElectionType              2     Primary  1454
# TotalVote                                                         12863.7962
# Clinton                                                          5973.738054
# Obama                                                            6178.122625
# MalesPer100Females                                                  99.24669
# AgeBelow35                                                         45.756074
# Age35to65                                                          39.487968
# Age65andAbove                                                      14.759873
# White                                                              85.486356
# Black                                                              11.098938
# Asian                                                               1.217463
# AmericanIndian                                                      1.526651
# Hawaiian                                                            0.060161
# Hispanic                                                            6.515026
# HighSchool                                                         77.518779
# Bachelors                                                          17.029839
# Poverty                                                            13.465976
# IncomeAbove75K                                                     14.571025
# MedianIncome                                                    40026.156592
# AverageIncome                                                   27505.110656
# UnemployRate                                                        4.645826
# ManfEmploy                                                         10.251324
# SpeakingNonEnglish                                                  7.974885
# Medicare                                                        15638.312788
# MedicareRate                                                    17054.747696
# SocialSecurity                                                  17643.782383
# SocialSecurityRate                                              19873.229131
# RetiredWorkers                                                  11278.154865
# Disabilities                                                     2774.347374
# DisabilitiesRate                                                 2553.378534
# Homeowner                                                          73.621889
# SameHouse1995and2000                                               58.015265
# Pop                                                            114360.369603
# PopDensity                                                        343.683362
# LandArea                                                         1042.831221
# FarmArea                                                          266.322483
# Obama_margin                                                      204.384571
# Obama_margin_percent                                               -0.037326
# Obama_wins                2       False   913
#
#                                       min                  25%  \
# County
# State
# Region
# FIPS                               1001.0              13157.0
# ElectionDate          2008-01-03 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                            13.0                732.0
# Clinton                               4.0                329.0
# Obama                                 4.0                254.0
# MalesPer100Females                   76.2                 94.9
# AgeBelow35                           29.1                 42.1
# Age35to65                            18.6                 38.0
# Age65andAbove                         2.2                 12.0
# White                                15.7                 78.4
# Black                                 0.1                  0.6
# Asian                                 0.1                  0.3
# AmericanIndian                        0.1                  0.2
# Hawaiian                              0.0                  0.0
# Hispanic                              0.1                  1.3
# HighSchool                           52.9                 70.8
# Bachelors                             5.4                 11.3
# Poverty                               2.6                  9.8
# IncomeAbove75K                        3.5                  9.2
# MedianIncome                      19407.0              32707.0
# AverageIncome                      5148.0             23128.75
# UnemployRate                          1.9                  3.6
# ManfEmploy                       0.243724             4.615268
# SpeakingNonEnglish                    0.4                  3.0
# Medicare                              7.0               2249.0
# MedicareRate                         60.0              13899.0
# SocialSecurity                       85.0               2630.0
# SocialSecurityRate                 1518.0              16617.0
# RetiredWorkers                       55.0               1580.0
# Disabilities                          4.0                266.0
# DisabilitiesRate                    125.0               1332.0
# Homeowner                            19.6                 69.9
# SameHouse1995and2000                 15.4                 53.4
# Pop                                 372.0              12721.0
# PopDensity                            0.2                 20.2
# LandArea                              2.0                444.0
# FarmArea                              1.0                 77.0
# Obama_margin                    -178697.0               -743.0
# Obama_margin_percent            -0.809318            -0.244681
# Obama_wins
#
#                                       50%                  75%  \
# County
# State
# Region
# FIPS                              25007.0              36095.0
# ElectionDate          2008-02-05 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                          2330.0               6418.0
# Clinton                            1106.0               3200.0
# Obama                               878.0               2749.0
# MalesPer100Females                   97.6                100.7
# AgeBelow35                           45.4                 48.9
# Age35to65                            39.6                 41.3
# Age65andAbove                        14.4                 17.2
# White                                92.1                 97.2
# Black                                 3.2                15.15
# Asian                                 0.5                  1.1
# AmericanIndian                        0.4                  0.9
# Hawaiian                              0.0                  0.1
# Hispanic                              2.6                  6.4
# HighSchool                           79.1                 84.3
# Bachelors                            14.6                 19.9
# Poverty                              12.9                 16.5
# IncomeAbove75K                       11.9               16.925
# MedianIncome                      37846.0              44276.0
# AverageIncome                     26086.0             29935.25
# UnemployRate                          4.4                  5.4
# ManfEmploy                       8.672499            13.995411
# SpeakingNonEnglish                    4.5                  8.3
# Medicare                           4443.5             10839.75
# MedicareRate                      16894.0              19970.0
# SocialSecurity                     5300.0              13170.0
# SocialSecurityRate                20021.0              23159.0
# RetiredWorkers                     3095.0               8020.0
# Disabilities                        685.0               1702.0
# DisabilitiesRate                   2154.0               3400.0
# Homeowner                            75.1                 78.9
# SameHouse1995and2000                58.75                 63.4
# Pop                               26685.0              71875.0
# PopDensity                           45.0                123.5
# LandArea                            621.0                939.0
# FarmArea                            183.0                327.5
# Obama_margin                         -4.0                331.0
# Obama_margin_percent            -0.019769             0.181023
# Obama_wins
#
#                                       max            std
# County
# State
# Region
# FIPS                              53077.0   15270.200219
# ElectionDate          2008-02-12 00:00:00
# ElectionType
# TotalVote                       1413869.0   53071.884245
# Clinton                          771700.0   25402.029497
# Obama                            743686.0   27477.231157
# MalesPer100Females                  200.9       9.794664
# AgeBelow35                           75.8       5.522395
# Age35to65                            56.5       3.405048
# Age65andAbove                        33.7       4.033575
# White                                99.8      15.924771
# Black                                82.8      15.719129
# Asian                                32.9       2.320598
# AmericanIndian                       76.8       4.817089
# Hawaiian                              1.4       0.126917
# Hispanic                             80.5      10.430744
# HighSchool                           97.0       8.565703
# Bachelors                            63.7       8.465203
# Poverty                              36.0       4.912627
# IncomeAbove75K                       57.3       8.305824
# MedianIncome                      98245.0   11029.060135
# AverageIncome                     93377.0    7189.672465
# UnemployRate                         15.3       1.580332
# ManfEmploy                      57.229045       7.342402
# SpeakingNonEnglish                   80.5       9.496264
# Medicare                        1059297.0   44742.955996
# MedicareRate                      58686.0    5205.686945
# SocialSecurity                  1047590.0    47253.22598
# SocialSecurityRate                41943.0    4954.322411
# RetiredWorkers                   681035.0    31172.79273
# Disabilities                     400125.0   12927.803443
# DisabilitiesRate                  13349.0    1633.806979
# Homeowner                            89.6       7.995113
# SameHouse1995and2000                 78.8       7.504476
# Pop                             9948081.0  376421.796136
# PopDensity                        70190.8     2266.25249
# LandArea                          20105.0    1534.800778
# FarmArea                           4595.0      339.57063
# Obama_margin                     429052.0   13201.304573
# Obama_margin_percent             0.726098       0.303184
# Obama_wins

# %% [markdown]
# Now we have a data set just of the previous primary elections (notice that we do not have any missing values for `Clinton`, `Obama`, or `TotalVote`).

# %% [markdown]
# ## Engineer features

# %% [markdown]
# Often when we are building models, we may want to transform the data in some way that doesn't rely on past or future data. This might be something like multiplying two columns together to create an interaction. Alternatively, it might be creating a new variable to indicate whether a state has some special meaning for either Clinton or Obama. As long as we can create this new feature using only a single row of data, we can go ahead and do that now.

# %% [markdown]
# However, if we instead are creating a new feature where we have to use data from other rows, this is a learning problem, and we should wait until we have a smaller training and validation sets set up, which we will do in the next section. An example of this might be if we wanted to create a new feature that was the average number of `MalesPer100Females` for the whole training data set. If we did this, we would be including information that we should not have yet in this average. Specifically, we would be using data that we are trying to predict on to compute the average, and the average is naturally going to include information about this data. This is bad practice when building a model because you obviously cannot do this when you are deploying a model in practice. There is no way to use data that doesn't exist yet to predict that data!

# %% [markdown]
# I will not include an specific new features here, but when you are building a model for the competition, you may want to. I'll leave a blank cell to invite you to do so.

# %%
# Load the dataset
obama_df = pd.read_csv('Obama.csv')

# Convert date to datetime and split data
obama_df["ElectionDate"] = pd.to_datetime(obama_df["ElectionDate"])
elect_df_train = obama_df[obama_df["ElectionDate"] < pd.to_datetime("2/19/2008")].copy()

# Calculate Obama_margin and Obama_margin_percent
elect_df_train["Obama_margin"] = elect_df_train["Obama"] - elect_df_train["Clinton"]
elect_df_train["Obama_margin_percent"] = elect_df_train["Obama_margin"] / elect_df_train["TotalVote"]

# Feature Engineering
# 1. Interaction Feature - Product of Poverty and Unemployment Rate
elect_df_train['Poverty_Unemploy_Interaction'] = elect_df_train['Poverty'] * elect_df_train['UnemployRate']

# 2. Indicator for High Hispanic Population
elect_df_train['High_Hispanic'] = (elect_df_train['Hispanic'] > 15).astype(int)  # 15% as a threshold

# 3. Transformation - Log of Population Density
elect_df_train['Log_PopDensity'] = np.log(elect_df_train['PopDensity'] + 1)  # Adding 1 to avoid log(0)

# 4. Normalized Median Income
max_income = elect_df_train['MedianIncome'].max()
elect_df_train['Normalized_Income'] = elect_df_train['MedianIncome'] / max_income

# 5. Age Group Ratio - Proportion of population in the age group below 35
elect_df_train['YoungPopulationRatio'] = elect_df_train['AgeBelow35'] / elect_df_train['Pop']

# Note: You can create additional features based on your hypothesis about what might impact the vote share.

# Check the new features
print(elect_df_train.head())
# Out:
#       County State   Region   FIPS ElectionDate ElectionType  TotalVote  \
# 0      Adair    IA  Midwest  19001   2008-01-03     Caucuses       75.0
# 1      Adams    IA  Midwest  19003   2008-01-03     Caucuses       50.0
# 2  Allamakee    IA  Midwest  19005   2008-01-03     Caucuses       80.0
# 3  Appanoose    IA  Midwest  19007   2008-01-03     Caucuses       60.0
# 4    Audubon    IA  Midwest  19009   2008-01-03     Caucuses       48.0
#
#    Clinton  Obama  MalesPer100Females  AgeBelow35  Age35to65  Age65andAbove  \
# 0     22.0   24.0                96.7        37.7       40.3           21.9
# 1     18.0    7.0                96.8        37.1       40.8           22.1
# 2     25.0   33.0               104.5        41.5       40.8           17.7
# 3     17.0   10.0                94.0        42.0       39.2           18.9
# 4     16.0   17.0                94.7        37.4       40.2           22.5
#
#    White  Black  Asian  AmericanIndian  Hawaiian  Hispanic  HighSchool  \
# 0   99.2    0.1    0.5             NaN       0.0       0.8        87.8
# 1   99.2    NaN    0.2             0.5       0.0       0.6        84.5
# 2   99.0    0.2    0.2             0.3       0.0       6.9        81.4
# 3   98.5    0.7    0.4             0.1       0.0       1.1        81.4
# 4   99.3    0.2    0.2             0.1       0.0       0.6        82.5
#
#    Bachelors  Poverty  IncomeAbove75K  MedianIncome  AverageIncome  \
# 0       11.2      9.7             8.6       39568.0        29222.0
# 1       12.0     10.6             7.8       35296.0        27297.0
# 2       14.4     10.8            10.7       36822.0        25579.0
# 3       12.2     14.9             6.6       31764.0        23705.0
# 4       12.3      9.2             9.7       38941.0        31100.0
#
#    UnemployRate  ManfEmploy  SpeakingNonEnglish  Medicare  MedicareRate  \
# 0           3.2   12.916739                 2.0    1551.0       19735.0
# 1           4.6    6.964421                 1.6     978.0       22936.0
# 2           4.6   16.473466                 8.2    2838.0       19294.0
# 3           5.4   15.080881                 2.5    3072.0       22479.0
# 4           4.1    8.333333                 2.7    1472.0       22797.0
#
#    SocialSecurity  SocialSecurityRate  RetiredWorkers  Disabilities  \
# 0          1825.0             23222.0          1230.0          90.0
# 1          1110.0             26032.0           720.0          78.0
# 2          3270.0             22231.0          2245.0         186.0
# 3          3415.0             24989.0          2050.0         453.0
# 4          1740.0             26947.0          1150.0          79.0
#
#    DisabilitiesRate  Homeowner  SameHouse1995and2000    Pop  PopDensity  \
# 0            1145.0       75.0                  66.0   7714        13.5
# 1            1829.0       74.7                  65.4   4192         9.9
# 2            1265.0       76.4                  64.1  14796        23.1
# 3            3315.0       74.0                  60.2  13422        27.0
# 4            1223.0       79.2                  70.4   6278        14.2
#
#    LandArea  FarmArea  Obama_margin  Obama_margin_percent  \
# 0     570.0     373.0           2.0              0.026667
# 1     425.0     238.0         -11.0             -0.220000
# 2     659.0     326.0           8.0              0.100000
# 3     516.0     236.0          -7.0             -0.116667
# 4     444.0     261.0           1.0              0.020833
#
#    Poverty_Unemploy_Interaction  High_Hispanic  Log_PopDensity  \
# 0                         31.04              0        2.674149
# 1                         48.76              0        2.388763
# 2                         49.68              0        3.182212
# 3                         80.46              0        3.332205
# 4                         37.72              0        2.721295
#
#    Normalized_Income  YoungPopulationRatio
# 0           0.402748              0.004887
# 1           0.359265              0.008850
# 2           0.374798              0.002805
# 3           0.323314              0.003129
# 4           0.396366              0.005957

# %%
summarize_dataframe(elect_df_train)
# Out:
#                                    Data Type  Missing Values  Unique Values  \
# County                                object               0           1138
# State                                 object               0             30
# Region                                object               0              4
# FIPS                                   int64               0           1737
# ElectionDate                  datetime64[ns]               0              9
# ElectionType                          object               0              2
# TotalVote                            float64               0           1490
# Clinton                              float64               0           1338
# Obama                                float64               0           1314
# MalesPer100Females                   float64               0            344
# AgeBelow35                           float64               0            274
# Age35to65                            float64               0            195
# Age65andAbove                        float64               0            209
# White                                float64               0            469
# Black                                float64              42            429
# Asian                                float64              42             97
# AmericanIndian                       float64              56            125
# Hawaiian                             float64               0             13
# Hispanic                             float64               0            281
# HighSchool                           float64               1            360
# Bachelors                            float64               1            342
# Poverty                              float64               0            236
# IncomeAbove75K                       float64               1            328
# MedianIncome                         float64               0           1688
# AverageIncome                        float64              29           1619
# UnemployRate                         float64               0             92
# ManfEmploy                           float64             171           1566
# SpeakingNonEnglish                   float64               1            296
# Medicare                             float64               1           1628
# MedicareRate                         float64               1           1651
# SocialSecurity                       float64               0           1394
# SocialSecurityRate                   float64               0           1664
# RetiredWorkers                       float64               0           1222
# Disabilities                         float64               4           1260
# DisabilitiesRate                     float64               4           1449
# Homeowner                            float64               1            350
# SameHouse1995and2000                 float64               1            345
# Pop                                    int64               0           1719
# PopDensity                           float64               0           1141
# LandArea                             float64               1           1018
# FarmArea                             float64              78            603
# Obama_margin                         float64               0           1267
# Obama_margin_percent                 float64               0           1701
# Poverty_Unemploy_Interaction         float64               0           1420
# High_Hispanic                          int64               0              2
# Log_PopDensity                       float64               0           1141
# Normalized_Income                    float64               0           1688
# YoungPopulationRatio                 float64               0           1737
#
#                                count unique         top  freq  \
# County                        1737.0   1138  Washington    19
# State                         1737.0     30          GA   159
# Region                        1737.0      4       South   811
# FIPS                          1737.0
# ElectionDate                  1737.0
# ElectionType                  1737.0      2     Primary  1454
# TotalVote                     1737.0
# Clinton                       1737.0
# Obama                         1737.0
# MalesPer100Females            1737.0
# AgeBelow35                    1737.0
# Age35to65                     1737.0
# Age65andAbove                 1737.0
# White                         1737.0
# Black                         1695.0
# Asian                         1695.0
# AmericanIndian                1681.0
# Hawaiian                      1737.0
# Hispanic                      1737.0
# HighSchool                    1736.0
# Bachelors                     1736.0
# Poverty                       1737.0
# IncomeAbove75K                1736.0
# MedianIncome                  1737.0
# AverageIncome                 1708.0
# UnemployRate                  1737.0
# ManfEmploy                    1566.0
# SpeakingNonEnglish            1736.0
# Medicare                      1736.0
# MedicareRate                  1736.0
# SocialSecurity                1737.0
# SocialSecurityRate            1737.0
# RetiredWorkers                1737.0
# Disabilities                  1733.0
# DisabilitiesRate              1733.0
# Homeowner                     1736.0
# SameHouse1995and2000          1736.0
# Pop                           1737.0
# PopDensity                    1737.0
# LandArea                      1736.0
# FarmArea                      1659.0
# Obama_margin                  1737.0
# Obama_margin_percent          1737.0
# Poverty_Unemploy_Interaction  1737.0
# High_Hispanic                 1737.0
# Log_PopDensity                1737.0
# Normalized_Income             1737.0
# YoungPopulationRatio          1737.0
#
#                                                        mean  \
# County
# State
# Region
# FIPS                                           25907.716753
# ElectionDate                  2008-02-03 09:22:54.093264128
# ElectionType
# TotalVote                                        12863.7962
# Clinton                                         5973.738054
# Obama                                           6178.122625
# MalesPer100Females                                 99.24669
# AgeBelow35                                        45.756074
# Age35to65                                         39.487968
# Age65andAbove                                     14.759873
# White                                             85.486356
# Black                                             11.098938
# Asian                                              1.217463
# AmericanIndian                                     1.526651
# Hawaiian                                           0.060161
# Hispanic                                           6.515026
# HighSchool                                        77.518779
# Bachelors                                         17.029839
# Poverty                                           13.465976
# IncomeAbove75K                                    14.571025
# MedianIncome                                   40026.156592
# AverageIncome                                  27505.110656
# UnemployRate                                       4.645826
# ManfEmploy                                        10.251324
# SpeakingNonEnglish                                 7.974885
# Medicare                                       15638.312788
# MedicareRate                                   17054.747696
# SocialSecurity                                 17643.782383
# SocialSecurityRate                             19873.229131
# RetiredWorkers                                 11278.154865
# Disabilities                                    2774.347374
# DisabilitiesRate                                2553.378534
# Homeowner                                         73.621889
# SameHouse1995and2000                              58.015265
# Pop                                           114360.369603
# PopDensity                                       343.683362
# LandArea                                        1042.831221
# FarmArea                                         266.322483
# Obama_margin                                     204.384571
# Obama_margin_percent                              -0.037326
# Poverty_Unemploy_Interaction                      66.611917
# High_Hispanic                                      0.107081
# Log_PopDensity                                     4.016772
# Normalized_Income                                  0.407412
# YoungPopulationRatio                               0.003276
#
#                                               min                  25%  \
# County
# State
# Region
# FIPS                                       1001.0              13157.0
# ElectionDate                  2008-01-03 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                                    13.0                732.0
# Clinton                                       4.0                329.0
# Obama                                         4.0                254.0
# MalesPer100Females                           76.2                 94.9
# AgeBelow35                                   29.1                 42.1
# Age35to65                                    18.6                 38.0
# Age65andAbove                                 2.2                 12.0
# White                                        15.7                 78.4
# Black                                         0.1                  0.6
# Asian                                         0.1                  0.3
# AmericanIndian                                0.1                  0.2
# Hawaiian                                      0.0                  0.0
# Hispanic                                      0.1                  1.3
# HighSchool                                   52.9                 70.8
# Bachelors                                     5.4                 11.3
# Poverty                                       2.6                  9.8
# IncomeAbove75K                                3.5                  9.2
# MedianIncome                              19407.0              32707.0
# AverageIncome                              5148.0             23128.75
# UnemployRate                                  1.9                  3.6
# ManfEmploy                               0.243724             4.615268
# SpeakingNonEnglish                            0.4                  3.0
# Medicare                                      7.0               2249.0
# MedicareRate                                 60.0              13899.0
# SocialSecurity                               85.0               2630.0
# SocialSecurityRate                         1518.0              16617.0
# RetiredWorkers                               55.0               1580.0
# Disabilities                                  4.0                266.0
# DisabilitiesRate                            125.0               1332.0
# Homeowner                                    19.6                 69.9
# SameHouse1995and2000                         15.4                 53.4
# Pop                                         372.0              12721.0
# PopDensity                                    0.2                 20.2
# LandArea                                      2.0                444.0
# FarmArea                                      1.0                 77.0
# Obama_margin                            -178697.0               -743.0
# Obama_margin_percent                    -0.809318            -0.244681
# Poverty_Unemploy_Interaction                 7.14                35.97
# High_Hispanic                                 0.0                  0.0
# Log_PopDensity                           0.182322             3.054001
# Normalized_Income                        0.197537             0.332913
# YoungPopulationRatio                     0.000005             0.000651
#
#                                               50%                  75%  \
# County
# State
# Region
# FIPS                                      25007.0              36095.0
# ElectionDate                  2008-02-05 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                                  2330.0               6418.0
# Clinton                                    1106.0               3200.0
# Obama                                       878.0               2749.0
# MalesPer100Females                           97.6                100.7
# AgeBelow35                                   45.4                 48.9
# Age35to65                                    39.6                 41.3
# Age65andAbove                                14.4                 17.2
# White                                        92.1                 97.2
# Black                                         3.2                15.15
# Asian                                         0.5                  1.1
# AmericanIndian                                0.4                  0.9
# Hawaiian                                      0.0                  0.1
# Hispanic                                      2.6                  6.4
# HighSchool                                   79.1                 84.3
# Bachelors                                    14.6                 19.9
# Poverty                                      12.9                 16.5
# IncomeAbove75K                               11.9               16.925
# MedianIncome                              37846.0              44276.0
# AverageIncome                             26086.0             29935.25
# UnemployRate                                  4.4                  5.4
# ManfEmploy                               8.672499            13.995411
# SpeakingNonEnglish                            4.5                  8.3
# Medicare                                   4443.5             10839.75
# MedicareRate                              16894.0              19970.0
# SocialSecurity                             5300.0              13170.0
# SocialSecurityRate                        20021.0              23159.0
# RetiredWorkers                             3095.0               8020.0
# Disabilities                                685.0               1702.0
# DisabilitiesRate                           2154.0               3400.0
# Homeowner                                    75.1                 78.9
# SameHouse1995and2000                        58.75                 63.4
# Pop                                       26685.0              71875.0
# PopDensity                                   45.0                123.5
# LandArea                                    621.0                939.0
# FarmArea                                    183.0                327.5
# Obama_margin                                 -4.0                331.0
# Obama_margin_percent                    -0.019769             0.181023
# Poverty_Unemploy_Interaction                55.86                84.94
# High_Hispanic                                 0.0                  0.0
# Log_PopDensity                           3.828641             4.824306
# Normalized_Income                        0.385221             0.450669
# YoungPopulationRatio                     0.001751             0.003536
#
#                                               max            std
# County
# State
# Region
# FIPS                                      53077.0   15270.200219
# ElectionDate                  2008-02-12 00:00:00
# ElectionType
# TotalVote                               1413869.0   53071.884245
# Clinton                                  771700.0   25402.029497
# Obama                                    743686.0   27477.231157
# MalesPer100Females                          200.9       9.794664
# AgeBelow35                                   75.8       5.522395
# Age35to65                                    56.5       3.405048
# Age65andAbove                                33.7       4.033575
# White                                        99.8      15.924771
# Black                                        82.8      15.719129
# Asian                                        32.9       2.320598
# AmericanIndian                               76.8       4.817089
# Hawaiian                                      1.4       0.126917
# Hispanic                                     80.5      10.430744
# HighSchool                                   97.0       8.565703
# Bachelors                                    63.7       8.465203
# Poverty                                      36.0       4.912627
# IncomeAbove75K                               57.3       8.305824
# MedianIncome                              98245.0   11029.060135
# AverageIncome                             93377.0    7189.672465
# UnemployRate                                 15.3       1.580332
# ManfEmploy                              57.229045       7.342402
# SpeakingNonEnglish                           80.5       9.496264
# Medicare                                1059297.0   44742.955996
# MedicareRate                              58686.0    5205.686945
# SocialSecurity                          1047590.0    47253.22598
# SocialSecurityRate                        41943.0    4954.322411
# RetiredWorkers                           681035.0    31172.79273
# Disabilities                             400125.0   12927.803443
# DisabilitiesRate                          13349.0    1633.806979
# Homeowner                                    89.6       7.995113
# SameHouse1995and2000                         78.8       7.504476
# Pop                                     9948081.0  376421.796136
# PopDensity                                70190.8     2266.25249
# LandArea                                  20105.0    1534.800778
# FarmArea                                   4595.0      339.57063
# Obama_margin                             429052.0   13201.304573
# Obama_margin_percent                     0.726098       0.303184
# Poverty_Unemploy_Interaction               369.15      43.021074
# High_Hispanic                                 1.0       0.309305
# Log_PopDensity                          11.158987       1.610584
# Normalized_Income                             1.0       0.112261
# YoungPopulationRatio                     0.102957       0.006595

# %% [markdown]
# ## Split into `smaller_train` and `validation` Data Sets

# %% [markdown]
# However, we are not done yet manipulating our data. A best practice in machine learning is to further split up the training set into a smaller training set and a validation set. You can compare the performance of candidate models (each trained on the smaller training set) on the validation set. This `smaller_train` data set becomes our laboratory to test out different modeling decisions and try them out on the `validation` data set.
#
# The following code randomly splits your training set into a smaller training set (75% of the training data) and a validation set (25% of the training data).

# %%
elect_df_smaller_train, elect_df_validation = train_test_split(elect_df_train, test_size=.25, random_state=201)

# %% [markdown]
# The test (or _validation_) data set is 25% of the original data. We also include the parameter `random_state=201` in the function call. This is because the function `train_test_split` randomly splits your data. This is good practice. However, if we let it randomly split our data, everytime we run our code something different will happen. We pass an initial _seed_ to the randomness generator in the function which makes the function give us _the same random split_ each time. This helps us with reproducibility with the code.

# %%
summarize_dataframe(elect_df_smaller_train)
# Out:
#                                    Data Type  Missing Values  Unique Values  \
# County                                object               0            921
# State                                 object               0             30
# Region                                object               0              4
# FIPS                                   int64               0           1302
# ElectionDate                  datetime64[ns]               0              9
# ElectionType                          object               0              2
# TotalVote                            float64               0           1137
# Clinton                              float64               0           1041
# Obama                                float64               0           1048
# MalesPer100Females                   float64               0            309
# AgeBelow35                           float64               0            262
# Age35to65                            float64               0            180
# Age65andAbove                        float64               0            197
# White                                float64               0            431
# Black                                float64              28            373
# Asian                                float64              33             92
# AmericanIndian                       float64              43            104
# Hawaiian                             float64               0             13
# Hispanic                             float64               0            252
# HighSchool                           float64               1            341
# Bachelors                            float64               1            317
# Poverty                              float64               0            231
# IncomeAbove75K                       float64               1            297
# MedianIncome                         float64               0           1273
# AverageIncome                        float64              24           1218
# UnemployRate                         float64               0             86
# ManfEmploy                           float64             133           1169
# SpeakingNonEnglish                   float64               1            262
# Medicare                             float64               1           1237
# MedicareRate                         float64               1           1256
# SocialSecurity                       float64               0           1082
# SocialSecurityRate                   float64               0           1250
# RetiredWorkers                       float64               0            984
# Disabilities                         float64               3           1007
# DisabilitiesRate                     float64               3           1148
# Homeowner                            float64               1            321
# SameHouse1995and2000                 float64               1            322
# Pop                                    int64               0           1290
# PopDensity                           float64               0            925
# LandArea                             float64               1            855
# FarmArea                             float64              64            533
# Obama_margin                         float64               0           1000
# Obama_margin_percent                 float64               0           1281
# Poverty_Unemploy_Interaction         float64               0           1128
# High_Hispanic                          int64               0              2
# Log_PopDensity                       float64               0            925
# Normalized_Income                    float64               0           1273
# YoungPopulationRatio                 float64               0           1302
#
#                                count unique       top  freq  \
# County                        1302.0    921  Franklin    15
# State                         1302.0     30        GA   120
# Region                        1302.0      4     South   608
# FIPS                          1302.0
# ElectionDate                  1302.0
# ElectionType                  1302.0      2   Primary  1094
# TotalVote                     1302.0
# Clinton                       1302.0
# Obama                         1302.0
# MalesPer100Females            1302.0
# AgeBelow35                    1302.0
# Age35to65                     1302.0
# Age65andAbove                 1302.0
# White                         1302.0
# Black                         1274.0
# Asian                         1269.0
# AmericanIndian                1259.0
# Hawaiian                      1302.0
# Hispanic                      1302.0
# HighSchool                    1301.0
# Bachelors                     1301.0
# Poverty                       1302.0
# IncomeAbove75K                1301.0
# MedianIncome                  1302.0
# AverageIncome                 1278.0
# UnemployRate                  1302.0
# ManfEmploy                    1169.0
# SpeakingNonEnglish            1301.0
# Medicare                      1301.0
# MedicareRate                  1301.0
# SocialSecurity                1302.0
# SocialSecurityRate            1302.0
# RetiredWorkers                1302.0
# Disabilities                  1299.0
# DisabilitiesRate              1299.0
# Homeowner                     1301.0
# SameHouse1995and2000          1301.0
# Pop                           1302.0
# PopDensity                    1302.0
# LandArea                      1301.0
# FarmArea                      1238.0
# Obama_margin                  1302.0
# Obama_margin_percent          1302.0
# Poverty_Unemploy_Interaction  1302.0
# High_Hispanic                 1302.0
# Log_PopDensity                1302.0
# Normalized_Income             1302.0
# YoungPopulationRatio          1302.0
#
#                                                        mean  \
# County
# State
# Region
# FIPS                                           25818.745008
# ElectionDate                  2008-02-03 10:47:00.276497664
# ElectionType
# TotalVote                                      13392.989247
# Clinton                                         6143.649002
# Obama                                           6504.599846
# MalesPer100Females                                99.207527
# AgeBelow35                                        45.685484
# Age35to65                                         39.486636
# Age65andAbove                                     14.833026
# White                                             85.265361
# Black                                             11.432496
# Asian                                              1.229236
# AmericanIndian                                      1.40421
# Hawaiian                                           0.059831
# Hispanic                                           6.626651
# HighSchool                                        77.334819
# Bachelors                                         16.964719
# Poverty                                           13.564747
# IncomeAbove75K                                    14.506226
# MedianIncome                                   39865.561444
# AverageIncome                                  27413.177621
# UnemployRate                                       4.657757
# ManfEmploy                                        10.152367
# SpeakingNonEnglish                                 8.054573
# Medicare                                        15923.04535
# MedicareRate                                    17168.58186
# SocialSecurity                                 17887.949309
# SocialSecurityRate                             19967.292627
# RetiredWorkers                                 11414.439324
# Disabilities                                    3000.488838
# DisabilitiesRate                                2582.117783
# Homeowner                                         73.566872
# SameHouse1995and2000                              58.050576
# Pop                                           118064.999232
# PopDensity                                       381.468126
# LandArea                                        1033.329746
# FarmArea                                         263.877221
# Obama_margin                                     360.950845
# Obama_margin_percent                              -0.028386
# Poverty_Unemploy_Interaction                      67.377819
# High_Hispanic                                      0.108295
# Log_PopDensity                                     4.007047
# Normalized_Income                                  0.405777
# YoungPopulationRatio                               0.003395
#
#                                               min                  25%  \
# County
# State
# Region
# FIPS                                       1001.0              13163.5
# ElectionDate                  2008-01-03 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                                    13.0               692.75
# Clinton                                       4.0               306.75
# Obama                                         4.0                249.0
# MalesPer100Females                           76.2                 94.8
# AgeBelow35                                   29.1                 42.0
# Age35to65                                    18.6                 37.9
# Age65andAbove                                 3.8               12.125
# White                                        15.7                77.95
# Black                                         0.1                  0.6
# Asian                                         0.1                  0.3
# AmericanIndian                                0.1                  0.2
# Hawaiian                                      0.0                  0.0
# Hispanic                                      0.1                  1.3
# HighSchool                                   52.9                 70.5
# Bachelors                                     5.4                 11.3
# Poverty                                       3.1                  9.9
# IncomeAbove75K                                3.5                  9.2
# MedianIncome                              21026.0              32645.0
# AverageIncome                              5148.0              22948.5
# UnemployRate                                  1.9                  3.6
# ManfEmploy                               0.243724              4.56542
# SpeakingNonEnglish                            0.4                  3.0
# Medicare                                      7.0               2224.0
# MedicareRate                                 60.0              13951.0
# SocialSecurity                               85.0               2550.0
# SocialSecurityRate                         1518.0             16705.75
# RetiredWorkers                               55.0               1557.5
# Disabilities                                  4.0                253.5
# DisabilitiesRate                            133.0               1349.5
# Homeowner                                    19.6                 70.0
# SameHouse1995and2000                         28.0                 53.5
# Pop                                         372.0              12312.5
# PopDensity                                    0.2                 20.1
# LandArea                                      2.0                442.0
# FarmArea                                      1.0                 76.0
# Obama_margin                            -178697.0               -698.5
# Obama_margin_percent                     -0.80817            -0.233282
# Poverty_Unemploy_Interaction                 7.14                35.96
# High_Hispanic                                 0.0                  0.0
# Log_PopDensity                           0.182322             3.049273
# Normalized_Income                        0.214016             0.332282
# YoungPopulationRatio                     0.000005             0.000666
#
#                                               50%                  75%  \
# County
# State
# Region
# FIPS                                      24026.0              36086.5
# ElectionDate                  2008-02-05 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                                  2305.0              6417.25
# Clinton                                    1080.5              3108.25
# Obama                                       864.5               2747.0
# MalesPer100Females                           97.5                100.8
# AgeBelow35                                   45.4                 48.8
# Age35to65                                    39.6                 41.3
# Age65andAbove                                14.5                 17.4
# White                                        92.0                 97.1
# Black                                         3.4               16.025
# Asian                                         0.5                  1.1
# AmericanIndian                                0.4                  0.9
# Hawaiian                                      0.0                  0.1
# Hispanic                                      2.6                  6.4
# HighSchool                                   79.0                 84.0
# Bachelors                                    14.7                 20.0
# Poverty                                     12.95                 16.6
# IncomeAbove75K                               11.9                 16.6
# MedianIncome                              37578.5              43892.5
# AverageIncome                             26005.5             29829.75
# UnemployRate                                  4.4                  5.4
# ManfEmploy                                8.77246            13.563803
# SpeakingNonEnglish                            4.5                  8.2
# Medicare                                   4356.0              10614.0
# MedicareRate                              16988.0              20014.0
# SocialSecurity                             5222.5              13040.0
# SocialSecurityRate                        20155.0             23227.25
# RetiredWorkers                             3060.0              7831.25
# Disabilities                                672.0               1653.5
# DisabilitiesRate                           2159.0               3393.5
# Homeowner                                    75.1                 78.7
# SameHouse1995and2000                         58.7                 63.4
# Pop                                       25442.5             70329.75
# PopDensity                                   44.1                120.4
# LandArea                                    621.0                948.0
# FarmArea                                    183.5               322.75
# Obama_margin                                 -3.0                326.0
# Obama_margin_percent                    -0.013758             0.189612
# Poverty_Unemploy_Interaction                55.86                86.85
# High_Hispanic                                 0.0                  0.0
# Log_PopDensity                           3.808882             4.799091
# Normalized_Income                        0.382498             0.446766
# YoungPopulationRatio                     0.001811             0.003593
#
#                                               max            std
# County
# State
# Region
# FIPS                                      53077.0   15254.098491
# ElectionDate                  2008-02-12 00:00:00
# ElectionType
# TotalVote                               1413869.0   59063.233132
# Clinton                                  771700.0   28083.659257
# Obama                                    743686.0   30755.114644
# MalesPer100Females                          200.9       9.598902
# AgeBelow35                                   72.4       5.527622
# Age35to65                                    56.5       3.455792
# Age65andAbove                                33.7       4.011233
# White                                        99.8      16.020058
# Black                                        82.8      15.924989
# Asian                                        32.9       2.479033
# AmericanIndian                               76.1        4.18548
# Hawaiian                                      1.4       0.128878
# Hispanic                                     80.5      10.696667
# HighSchool                                   97.0       8.535001
# Bachelors                                    60.5       8.405201
# Poverty                                      36.0       4.978741
# IncomeAbove75K                               57.3       8.310121
# MedianIncome                              98245.0   11042.520767
# AverageIncome                             93377.0    7245.451951
# UnemployRate                                 15.3       1.597884
# ManfEmploy                              57.229045       7.256832
# SpeakingNonEnglish                           80.5       9.715848
# Medicare                                1059297.0   48845.376923
# MedicareRate                              58686.0    5316.264196
# SocialSecurity                          1047590.0   51282.662145
# SocialSecurityRate                        41943.0    4969.791412
# RetiredWorkers                           681035.0   33699.978544
# Disabilities                             400125.0   14704.884269
# DisabilitiesRate                          11608.0    1662.510152
# Homeowner                                    89.6       8.140812
# SameHouse1995and2000                         78.8       7.402014
# Pop                                     9948081.0  418009.732243
# PopDensity                                70190.8    2576.273037
# LandArea                                  20105.0    1511.525155
# FarmArea                                   4595.0      335.82249
# Obama_margin                             429052.0   14678.084359
# Obama_margin_percent                     0.726098       0.300369
# Poverty_Unemploy_Interaction               299.97      43.603619
# High_Hispanic                                 1.0       0.310872
# Log_PopDensity                          11.158987       1.631584
# Normalized_Income                             1.0       0.112398
# YoungPopulationRatio                     0.102957       0.006954

# %% [markdown]
# In our smaller training set, we now have 1302 data points. The other data is either in the test set or the validation set.

# %% [markdown]
# We also have missing data on a number of the numeric demographic data. However, even `ManfEmploy` which has the most missing data only has 133 missing data points out of a total of 1302 rows. Therefore, we probably don't want to just throw any of this data away.
#
# We need to _impute_ the missing values. There are a number of possible strategies, but the most common is to just assume that the missing value is equal to the average of the non-missing values. This is, in some ways, a very safe assumption. If the data is missing just because someone forgot to input it, then there is no reason to believe that the data is either above or below average, so we should just assume it is average.
#
# However, this strategy may not make sense with some data. Think about what else you might want to do.

# %% [markdown]
# To do the imputation, we will use an _object_ from the `sklearn` library called a _Transformer_. These transformers, unsurprisingly, transform data. We will see this pattern a lot when working with objects from `sklearn`, so it is worthwhile to understand how this thing works.
#
# First, we create the `SimpleImputer` and we tell it what kind of imputer we would like it to be. Below, we create one called `imputer` and we tell it that missing values are `np.nan` (a common way for numpy and pandas to represent missing values) and we tell it to impute using the mean of existing data. Note that we don't actually give it the data yet.

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %% [markdown]
# In order to impute anything, we need to `fit` the imputer. The imputer needs to know what the mean of all of the existing data is, so we give it the data set, and we let it learn the mean. After it has been fitted, we can use it to actually transform the data.

# %%
imputer.fit(elect_df_smaller_train.loc[:, "MalesPer100Females":"FarmArea"])
# Out:
# SimpleImputer()

# %% [markdown]
# Once we have `fit` the imputer (note that we fit all of the numeric rows at once, we don't need an imputer per column), we can then _transform_ the data.

# %%
elect_df_smaller_train.loc[:, "MalesPer100Females":"FarmArea"] = imputer.transform(elect_df_smaller_train.loc[:, "MalesPer100Females":"FarmArea"])

# %% [markdown]
# You likely got a warning above. This is due to a bug in `train_test_split` not letting pandas know that things are a copy. You can ignore it. Note that this is not an error, and the code does run just fine.

# %% [markdown]
# Notice how we were able to fix all of the missing values at once with the syntax `.loc[:, "MalesPer100Females":"FarmArea"]`. This tells the dataframe that we want all columns between `MalesPer100Females` and `FarmArea`. If you check back at the dataframe summary you will see that these are all of our numeric columns, so it should be everything. You need to be careful when using this syntax because you don't want to accidentally include columns that you don't intend to. However, it can be a convenient way to get a bunch of columns without explicitly writing down all of the names.

# %% [markdown]
# Run the summary function again. Now you see that no demographic/county columns have NA entries.

# %%
summarize_dataframe(elect_df_smaller_train)
# Out:
#                                    Data Type  Missing Values  Unique Values  \
# County                                object               0            921
# State                                 object               0             30
# Region                                object               0              4
# FIPS                                   int64               0           1302
# ElectionDate                  datetime64[ns]               0              9
# ElectionType                          object               0              2
# TotalVote                            float64               0           1137
# Clinton                              float64               0           1041
# Obama                                float64               0           1048
# MalesPer100Females                   float64               0            309
# AgeBelow35                           float64               0            262
# Age35to65                            float64               0            180
# Age65andAbove                        float64               0            197
# White                                float64               0            431
# Black                                float64               0            374
# Asian                                float64               0             93
# AmericanIndian                       float64               0            105
# Hawaiian                             float64               0             13
# Hispanic                             float64               0            252
# HighSchool                           float64               0            342
# Bachelors                            float64               0            318
# Poverty                              float64               0            231
# IncomeAbove75K                       float64               0            298
# MedianIncome                         float64               0           1273
# AverageIncome                        float64               0           1219
# UnemployRate                         float64               0             86
# ManfEmploy                           float64               0           1170
# SpeakingNonEnglish                   float64               0            263
# Medicare                             float64               0           1238
# MedicareRate                         float64               0           1257
# SocialSecurity                       float64               0           1082
# SocialSecurityRate                   float64               0           1250
# RetiredWorkers                       float64               0            984
# Disabilities                         float64               0           1008
# DisabilitiesRate                     float64               0           1149
# Homeowner                            float64               0            322
# SameHouse1995and2000                 float64               0            323
# Pop                                    int64               0           1290
# PopDensity                           float64               0            925
# LandArea                             float64               0            856
# FarmArea                             float64               0            534
# Obama_margin                         float64               0           1000
# Obama_margin_percent                 float64               0           1281
# Poverty_Unemploy_Interaction         float64               0           1128
# High_Hispanic                          int64               0              2
# Log_PopDensity                       float64               0            925
# Normalized_Income                    float64               0           1273
# YoungPopulationRatio                 float64               0           1302
#
#                                count unique       top  freq  \
# County                        1302.0    921  Franklin    15
# State                         1302.0     30        GA   120
# Region                        1302.0      4     South   608
# FIPS                          1302.0
# ElectionDate                  1302.0
# ElectionType                  1302.0      2   Primary  1094
# TotalVote                     1302.0
# Clinton                       1302.0
# Obama                         1302.0
# MalesPer100Females            1302.0
# AgeBelow35                    1302.0
# Age35to65                     1302.0
# Age65andAbove                 1302.0
# White                         1302.0
# Black                         1302.0
# Asian                         1302.0
# AmericanIndian                1302.0
# Hawaiian                      1302.0
# Hispanic                      1302.0
# HighSchool                    1302.0
# Bachelors                     1302.0
# Poverty                       1302.0
# IncomeAbove75K                1302.0
# MedianIncome                  1302.0
# AverageIncome                 1302.0
# UnemployRate                  1302.0
# ManfEmploy                    1302.0
# SpeakingNonEnglish            1302.0
# Medicare                      1302.0
# MedicareRate                  1302.0
# SocialSecurity                1302.0
# SocialSecurityRate            1302.0
# RetiredWorkers                1302.0
# Disabilities                  1302.0
# DisabilitiesRate              1302.0
# Homeowner                     1302.0
# SameHouse1995and2000          1302.0
# Pop                           1302.0
# PopDensity                    1302.0
# LandArea                      1302.0
# FarmArea                      1302.0
# Obama_margin                  1302.0
# Obama_margin_percent          1302.0
# Poverty_Unemploy_Interaction  1302.0
# High_Hispanic                 1302.0
# Log_PopDensity                1302.0
# Normalized_Income             1302.0
# YoungPopulationRatio          1302.0
#
#                                                        mean  \
# County
# State
# Region
# FIPS                                           25818.745008
# ElectionDate                  2008-02-03 10:47:00.276497664
# ElectionType
# TotalVote                                      13392.989247
# Clinton                                         6143.649002
# Obama                                           6504.599846
# MalesPer100Females                                99.207527
# AgeBelow35                                        45.685484
# Age35to65                                         39.486636
# Age65andAbove                                     14.833026
# White                                             85.265361
# Black                                             11.432496
# Asian                                              1.229236
# AmericanIndian                                      1.40421
# Hawaiian                                           0.059831
# Hispanic                                           6.626651
# HighSchool                                        77.334819
# Bachelors                                         16.964719
# Poverty                                           13.564747
# IncomeAbove75K                                    14.506226
# MedianIncome                                   39865.561444
# AverageIncome                                  27413.177621
# UnemployRate                                       4.657757
# ManfEmploy                                        10.152367
# SpeakingNonEnglish                                 8.054573
# Medicare                                        15923.04535
# MedicareRate                                    17168.58186
# SocialSecurity                                 17887.949309
# SocialSecurityRate                             19967.292627
# RetiredWorkers                                 11414.439324
# Disabilities                                    3000.488838
# DisabilitiesRate                                2582.117783
# Homeowner                                         73.566872
# SameHouse1995and2000                              58.050576
# Pop                                           118064.999232
# PopDensity                                       381.468126
# LandArea                                        1033.329746
# FarmArea                                         263.877221
# Obama_margin                                     360.950845
# Obama_margin_percent                              -0.028386
# Poverty_Unemploy_Interaction                      67.377819
# High_Hispanic                                      0.108295
# Log_PopDensity                                     4.007047
# Normalized_Income                                  0.405777
# YoungPopulationRatio                               0.003395
#
#                                               min                  25%  \
# County
# State
# Region
# FIPS                                       1001.0              13163.5
# ElectionDate                  2008-01-03 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                                    13.0               692.75
# Clinton                                       4.0               306.75
# Obama                                         4.0                249.0
# MalesPer100Females                           76.2                 94.8
# AgeBelow35                                   29.1                 42.0
# Age35to65                                    18.6                 37.9
# Age65andAbove                                 3.8               12.125
# White                                        15.7                77.95
# Black                                         0.1                  0.6
# Asian                                         0.1                  0.3
# AmericanIndian                                0.1                  0.2
# Hawaiian                                      0.0                  0.0
# Hispanic                                      0.1                  1.3
# HighSchool                                   52.9               70.525
# Bachelors                                     5.4                 11.3
# Poverty                                       3.1                  9.9
# IncomeAbove75K                                3.5                  9.2
# MedianIncome                              21026.0              32645.0
# AverageIncome                              5148.0             23070.75
# UnemployRate                                  1.9                  3.6
# ManfEmploy                               0.243724              5.00759
# SpeakingNonEnglish                            0.4                  3.0
# Medicare                                      7.0               2226.5
# MedicareRate                                 60.0             13954.75
# SocialSecurity                               85.0               2550.0
# SocialSecurityRate                         1518.0             16705.75
# RetiredWorkers                               55.0               1557.5
# Disabilities                                  4.0                255.0
# DisabilitiesRate                            133.0               1350.5
# Homeowner                                    19.6                 70.0
# SameHouse1995and2000                         28.0                 53.5
# Pop                                         372.0              12312.5
# PopDensity                                    0.2                 20.1
# LandArea                                      2.0                442.0
# FarmArea                                      1.0                79.25
# Obama_margin                            -178697.0               -698.5
# Obama_margin_percent                     -0.80817            -0.233282
# Poverty_Unemploy_Interaction                 7.14                35.96
# High_Hispanic                                 0.0                  0.0
# Log_PopDensity                           0.182322             3.049273
# Normalized_Income                        0.214016             0.332282
# YoungPopulationRatio                     0.000005             0.000666
#
#                                               50%                  75%  \
# County
# State
# Region
# FIPS                                      24026.0              36086.5
# ElectionDate                  2008-02-05 00:00:00  2008-02-05 00:00:00
# ElectionType
# TotalVote                                  2305.0              6417.25
# Clinton                                    1080.5              3108.25
# Obama                                       864.5               2747.0
# MalesPer100Females                           97.5                100.8
# AgeBelow35                                   45.4                 48.8
# Age35to65                                    39.6                 41.3
# Age65andAbove                                14.5                 17.4
# White                                        92.0                 97.1
# Black                                         3.8               15.175
# Asian                                         0.5                  1.2
# AmericanIndian                                0.4                  1.0
# Hawaiian                                      0.0                  0.1
# Hispanic                                      2.6                  6.4
# HighSchool                                   79.0                 84.0
# Bachelors                                    14.7                 20.0
# Poverty                                     12.95                 16.6
# IncomeAbove75K                               11.9                 16.6
# MedianIncome                              37578.5              43892.5
# AverageIncome                             26084.5              29743.5
# UnemployRate                                  4.4                  5.4
# ManfEmploy                               9.650411            12.874069
# SpeakingNonEnglish                            4.5                  8.2
# Medicare                                   4363.0             10643.25
# MedicareRate                              16988.5             20011.25
# SocialSecurity                             5222.5              13040.0
# SocialSecurityRate                        20155.0             23227.25
# RetiredWorkers                             3060.0              7831.25
# Disabilities                                675.5               1667.0
# DisabilitiesRate                           2161.5               3383.0
# Homeowner                                    75.1                 78.7
# SameHouse1995and2000                         58.7                 63.4
# Pop                                       25442.5             70329.75
# PopDensity                                   44.1                120.4
# LandArea                                    621.0               950.25
# FarmArea                                    197.0                315.0
# Obama_margin                                 -3.0                326.0
# Obama_margin_percent                    -0.013758             0.189612
# Poverty_Unemploy_Interaction                55.86                86.85
# High_Hispanic                                 0.0                  0.0
# Log_PopDensity                           3.808882             4.799091
# Normalized_Income                        0.382498             0.446766
# YoungPopulationRatio                     0.001811             0.003593
#
#                                               max            std
# County
# State
# Region
# FIPS                                      53077.0   15254.098491
# ElectionDate                  2008-02-12 00:00:00
# ElectionType
# TotalVote                               1413869.0   59063.233132
# Clinton                                  771700.0   28083.659257
# Obama                                    743686.0   30755.114644
# MalesPer100Females                          200.9       9.598902
# AgeBelow35                                   72.4       5.527622
# Age35to65                                    56.5       3.455792
# Age65andAbove                                33.7       4.011233
# White                                        99.8      16.020058
# Black                                        82.8      15.752688
# Asian                                        32.9        2.44739
# AmericanIndian                               76.1        4.11573
# Hawaiian                                      1.4       0.128878
# Hispanic                                     80.5      10.696667
# HighSchool                                   97.0        8.53172
# Bachelors                                    60.5        8.40197
# Poverty                                      36.0       4.978741
# IncomeAbove75K                               57.3       8.306926
# MedianIncome                              98245.0   11042.520767
# AverageIncome                             93377.0     7178.31118
# UnemployRate                                 15.3       1.597884
# ManfEmploy                              57.229045       6.875905
# SpeakingNonEnglish                           80.5       9.712114
# Medicare                                1059297.0   48826.601071
# MedicareRate                              58686.0    5314.220658
# SocialSecurity                          1047590.0   51282.662145
# SocialSecurityRate                        41943.0    4969.791412
# RetiredWorkers                           681035.0   33699.978544
# Disabilities                             400125.0   14687.920352
# DisabilitiesRate                          11608.0     1660.59224
# Homeowner                                    89.6       8.137683
# SameHouse1995and2000                         78.8       7.399169
# Pop                                     9948081.0  418009.732243
# PopDensity                                70190.8    2576.273037
# LandArea                                  20105.0    1510.944134
# FarmArea                                   4595.0     327.458282
# Obama_margin                             429052.0   14678.084359
# Obama_margin_percent                     0.726098       0.300369
# Poverty_Unemploy_Interaction               299.97      43.603619
# High_Hispanic                                 1.0       0.310872
# Log_PopDensity                          11.158987       1.631584
# Normalized_Income                             1.0       0.112398
# YoungPopulationRatio                     0.102957       0.006954

# %% [markdown]
# The one thing you need to be careful of is that we haven't imputed values for our _validation_ or _test_ data yet. At this point, we could not use any model we built to predict on these other datasets because they will have missing values in them, so we need to impute the missing values for them as well. However, we need to be sure we use _the same imputer_ to impute data for those. I.e., we don't refit the imputer. Why is this so important? What might go wrong if we don't? Think back to the discussion around feature engineering.

# %%
elect_df_validation.loc[:, "MalesPer100Females":"FarmArea"] = imputer.transform(elect_df_validation.loc[:, "MalesPer100Females":"FarmArea"])

# %% [markdown]
# Note that we have only imputed on our validation data set so far becuase at this stage of the process, our validation data set is a stand in for our testing data. We will impute on our testing data after we have chosen our models because at that point we will re-fit the imputer on the entire training data.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# Now that our data set is fully prepared, we can fit our first model. We will first fit a linear regression model. We have seen this before with Casino Jack, but this time, we will use this model to predict the values in a new dataset.

# %%
lm_1 = smf.ols(formula='Obama_margin_percent ~ Region + Black + HighSchool + Poverty + PopDensity + SpeakingNonEnglish + LandArea + MalesPer100Females + Log_PopDensity + Poverty_Unemploy_Interaction + High_Hispanic + Normalized_Income + YoungPopulationRatio', data=elect_df_smaller_train).fit()

# %%
lm_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Obama_margin_percent   R-squared:                       0.618
# Model:                              OLS   Adj. R-squared:                  0.614
# Method:                   Least Squares   F-statistic:                     148.8
# Date:                  Fri, 10 Nov 2023   Prob (F-statistic):          5.14e-257
# Time:                          15:35:40   Log-Likelihood:                 345.74
# No. Observations:                  1302   AIC:                            -661.5
# Df Residuals:                      1287   BIC:                            -583.9
# Df Model:                            14
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.5897      0.114     -5.187      0.000      -0.813      -0.367
# Region[T.Northeast]             -0.1943      0.023     -8.451      0.000      -0.239      -0.149
# Region[T.South]                 -0.2021      0.017    -11.962      0.000      -0.235      -0.169
# Region[T.West]                   0.1426      0.020      6.980      0.000       0.103       0.183
# Black                            0.0193      0.001     38.249      0.000       0.018       0.020
# HighSchool                       0.0100      0.001      8.606      0.000       0.008       0.012
# Poverty                         -0.0131      0.003     -4.201      0.000      -0.019      -0.007
# PopDensity                   -5.161e-06   2.33e-06     -2.216      0.027   -9.73e-06   -5.93e-07
# SpeakingNonEnglish               0.0018      0.001      1.836      0.067      -0.000       0.004
# LandArea                     -5.721e-06    4.4e-06     -1.301      0.193   -1.43e-05    2.91e-06
# Log_PopDensity                  -0.0100      0.006     -1.773      0.076      -0.021       0.001
# Poverty_Unemploy_Interaction    -0.0013      0.000     -5.277      0.000      -0.002      -0.001
# High_Hispanic                   -0.0475      0.027     -1.759      0.079      -0.100       0.005
# Normalized_Income               -0.0788      0.103     -0.765      0.445      -0.281       0.123
# YoungPopulationRatio            -3.9346      0.911     -4.319      0.000      -5.722      -2.147
# ==============================================================================
# Omnibus:                       18.124   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.121
# Skew:                           0.085   Prob(JB):                     4.75e-07
# Kurtosis:                       3.713   Cond. No.                     4.59e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.59e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# To evaluate the accuracy, we will use the self-defined `accuracy` function.

# %%
def accuracy(y_true, y_pred):
    """Function that returns a table showing RMSE and MAE."""
    acc_df = pd.DataFrame(data = {"RMSE": [mean_squared_error(y_true, y_pred)**(1/2)],
                                  "MAE": [mean_absolute_error(y_true, y_pred)],
                                  "R^2": [r2_score(y_true, y_pred)]})
    display(acc_df.style.hide(axis='index'))

# %% [markdown]
# Once a model has been trained, we need to actually predict over the new data set. We do that with the `.predict()` method.

# %%
lm_1_pred = lm_1.predict(elect_df_validation)

# %% [markdown]
# We can see our predictions.

# %%
lm_1_pred
# Out:
# 1700   -0.383618
# 569    -0.406230
# 564     0.131163
# 538    -0.308296
# 992    -0.157467
#           ...
# 921     0.110736
# 1449   -0.101024
# 1062    0.027212
# 1172   -0.371152
# 111     0.037952
# Length: 435, dtype: float64

# %% [markdown]
# Compare their accuracies on the validation set.

# %%
accuracy(elect_df_validation["Obama_margin_percent"], lm_1_pred)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f4b0d">
#   <thead>
#     <tr>
#       <th id="T_f4b0d_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_f4b0d_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f4b0d_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f4b0d_row0_col0" class="data row0 col0" >0.187891</td>
#       <td id="T_f4b0d_row0_col1" class="data row0 col1" >0.143283</td>
#       <td id="T_f4b0d_row0_col2" class="data row0 col2" >0.632447</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Regularized Regression Model

# %% [markdown]
# When variables are too closely correlated, linear regression has a problem estimating coefficients on the correlated variables. Consider the following example of multicollinearity between Medicare and Disabilities.

# %%
elect_df_smaller_train[["Medicare", "Disabilities"]].corr()
# Out:
#               Medicare  Disabilities
# Medicare      1.000000      0.914991
# Disabilities  0.914991      1.000000

# %% [markdown]
# Now train two models, one with Medicar and Disabilities and one with only Disabilities.

# %%
lm_with_mc = smf.ols(formula='Obama_margin_percent ~ Region + Black + HighSchool + Poverty + Medicare + Disabilities + MalesPer100Females + Log_PopDensity + Poverty_Unemploy_Interaction + High_Hispanic + Normalized_Income + YoungPopulationRatio', data=elect_df_smaller_train).fit()
lm_with_mc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Obama_margin_percent   R-squared:                       0.626
# Model:                              OLS   Adj. R-squared:                  0.622
# Method:                   Least Squares   F-statistic:                     154.0
# Date:                  Fri, 10 Nov 2023   Prob (F-statistic):          6.67e-263
# Time:                          15:37:36   Log-Likelihood:                 359.53
# No. Observations:                  1302   AIC:                            -689.1
# Df Residuals:                      1287   BIC:                            -611.5
# Df Model:                            14
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.7164      0.127     -5.646      0.000      -0.965      -0.467
# Region[T.Northeast]             -0.1911      0.023     -8.493      0.000      -0.235      -0.147
# Region[T.South]                 -0.2101      0.017    -12.599      0.000      -0.243      -0.177
# Region[T.West]                   0.1517      0.019      7.968      0.000       0.114       0.189
# Black                            0.0192      0.000     38.815      0.000       0.018       0.020
# HighSchool                       0.0100      0.001      8.704      0.000       0.008       0.012
# Poverty                         -0.0124      0.003     -4.054      0.000      -0.018      -0.006
# Medicare                     -1.336e-06   2.95e-07     -4.533      0.000   -1.91e-06   -7.58e-07
# Disabilities                  2.274e-06   9.17e-07      2.481      0.013    4.76e-07    4.07e-06
# MalesPer100Females               0.0007      0.001      1.193      0.233      -0.000       0.002
# Log_PopDensity                   0.0040      0.005      0.725      0.468      -0.007       0.015
# Poverty_Unemploy_Interaction    -0.0013      0.000     -5.459      0.000      -0.002      -0.001
# High_Hispanic                   -0.0068      0.021     -0.327      0.744      -0.048       0.034
# Normalized_Income               -0.0499      0.102     -0.491      0.624      -0.249       0.150
# YoungPopulationRatio            -3.3996      0.873     -3.892      0.000      -5.113      -1.686
# ==============================================================================
# Omnibus:                       17.450   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.917
# Skew:                           0.078   Prob(JB):                     8.67e-07
# Kurtosis:                       3.700   Cond. No.                     9.07e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.07e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
lm_without_mc = smf.ols(formula='Obama_margin_percent ~ Region + Black + HighSchool + Poverty + Medicare + Disabilities + MalesPer100Females + Log_PopDensity + Poverty_Unemploy_Interaction + High_Hispanic + Normalized_Income + YoungPopulationRatio', data=elect_df_smaller_train).fit()
lm_without_mc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     Obama_margin_percent   R-squared:                       0.626
# Model:                              OLS   Adj. R-squared:                  0.622
# Method:                   Least Squares   F-statistic:                     154.0
# Date:                  Fri, 10 Nov 2023   Prob (F-statistic):          6.67e-263
# Time:                          15:38:06   Log-Likelihood:                 359.53
# No. Observations:                  1302   AIC:                            -689.1
# Df Residuals:                      1287   BIC:                            -611.5
# Df Model:                            14
# Covariance Type:              nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                       -0.7164      0.127     -5.646      0.000      -0.965      -0.467
# Region[T.Northeast]             -0.1911      0.023     -8.493      0.000      -0.235      -0.147
# Region[T.South]                 -0.2101      0.017    -12.599      0.000      -0.243      -0.177
# Region[T.West]                   0.1517      0.019      7.968      0.000       0.114       0.189
# Black                            0.0192      0.000     38.815      0.000       0.018       0.020
# HighSchool                       0.0100      0.001      8.704      0.000       0.008       0.012
# Poverty                         -0.0124      0.003     -4.054      0.000      -0.018      -0.006
# Medicare                     -1.336e-06   2.95e-07     -4.533      0.000   -1.91e-06   -7.58e-07
# Disabilities                  2.274e-06   9.17e-07      2.481      0.013    4.76e-07    4.07e-06
# MalesPer100Females               0.0007      0.001      1.193      0.233      -0.000       0.002
# Log_PopDensity                   0.0040      0.005      0.725      0.468      -0.007       0.015
# Poverty_Unemploy_Interaction    -0.0013      0.000     -5.459      0.000      -0.002      -0.001
# High_Hispanic                   -0.0068      0.021     -0.327      0.744      -0.048       0.034
# Normalized_Income               -0.0499      0.102     -0.491      0.624      -0.249       0.150
# YoungPopulationRatio            -3.3996      0.873     -3.892      0.000      -5.113      -1.686
# ==============================================================================
# Omnibus:                       17.450   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.917
# Skew:                           0.078   Prob(JB):                     8.67e-07
# Kurtosis:                       3.700   Cond. No.                     9.07e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.07e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# How did the first regression model above (with both Medicare and Disabilities in it) decide to put a negative weight on Medicare and a positive weight on Disabilities? In the second model, Disabilities (which contains almost the same information as Medicare) has a negative weight.
#
# One way to avoid this multicollinearity problem is to make sure that you never pick variables that are too correlated. However, then you have to figure out what too correlated actually is, which will depend on the data set and whether or not there really is new information in each variable (Medicare and Disabilities are not 100% correlated!). This also is very difficult if you have lots of variables.
#
# A different solution to multicollinearity and overfitting in general is regularization. It works by penalizing a regression for the size of its coefficients. The further away from 0 a coefficient is; the bigger the penalty. This penalty prevents a regression from overreacting to outliers and/or placing extreme weights on two correlated variables (i.e., one large negative coefficient and one large positive coefficient).

# %% [markdown]
# ## LASSO Regression

# %% [markdown]
# The lasso, Least Absolute Shrinkage and Selection Operator, is a regularized regression model thats fits a linear regression by minimizing the usual sum of squared errors plus the complexity parameter (`alpha`) times the sum of the absolute values of the coefficients.  See ISL pp. 237-251, section 6.2.

# %% [markdown]
# However, for this model, we cannot use the same syntax that we used to come up with our dataset (it is an `sklearn` model, not a `statsmodel` model). So, we have to construct our dataset in a slightly different way. Moreover, if we don't have to worry about multi-collinearity, we might as well throw everything into our model, which would get quite tedious with the previous approach.
#
# Luckily, there is a solution. We can use very similar syntax to explicitly create a dataframe for us with exactly the variables we want. We can still write out the equation in something like natural language, we just give it to the `dmatrices` function from `patsy`. You can dive deeper into how this syntax works at [this](https://patsy.readthedocs.io/en/latest/formulas.html#) link. However, we still have the problem of writing out the formula. We can get around this by using some clever python list comprehension and text manipulation.
#
# Below we create a list of all the variables we want. We do this by looping through all of the columns in our training dataframe, and then added all columns that aren't in the list we don't want. The list we don't want includes some obvious things like `Clinton`, `Obama`, `TotalVote`, `Obama_margin_percent`, etc., i.e. things that we won't have in the testing data set. However, we also include `ElectionDate`, `State`, `County`, and `FIPS` in the things we want to throw out. Why?

# %%
variables = [variable for variable in elect_df_smaller_train.columns if variable not in ['FIPS', 'County', 'State', 'ElectionDate', 'TotalVote', 'Obama_margin', 'Obama_margin_percent', 'Obama_wins', 'Clinton', 'Obama']]

# %%
variables
# Out:
# ['Region',
#  'ElectionType',
#  'MalesPer100Females',
#  'AgeBelow35',
#  'Age35to65',
#  'Age65andAbove',
#  'White',
#  'Black',
#  'Asian',
#  'AmericanIndian',
#  'Hawaiian',
#  'Hispanic',
#  'HighSchool',
#  'Bachelors',
#  'Poverty',
#  'IncomeAbove75K',
#  'MedianIncome',
#  'AverageIncome',
#  'UnemployRate',
#  'ManfEmploy',
#  'SpeakingNonEnglish',
#  'Medicare',
#  'MedicareRate',
#  'SocialSecurity',
#  'SocialSecurityRate',
#  'RetiredWorkers',
#  'Disabilities',
#  'DisabilitiesRate',
#  'Homeowner',
#  'SameHouse1995and2000',
#  'Pop',
#  'PopDensity',
#  'LandArea',
#  'FarmArea',
#  'Poverty_Unemploy_Interaction',
#  'High_Hispanic',
#  'Log_PopDensity',
#  'Normalized_Income',
#  'YoungPopulationRatio']

# %% [markdown]
# Our variables are in two categories. The first two variables (`Region` and `ElectionType`) are categorical, and we want to make sure we dummy code those variables. The rest are all continuous. When we are using reguralized regression, since we penalize large regression coefficients, we need to make sure that every independent variable has roughly the same range. You should spend some time making sure that you understand and agree with this statement.
#
# In order to both a) ensure that all of the continuous variables have the same range and b) consistently apply the transformation, we are going to make use of the `standardize()` function built into the `patsy` syntax in order to transform these variables into new variables that are mean `0` and have standard deviation of `1`. To do this we are going to have to get a little clever in how we set up our formula.
#
# First, we are going to have to treat the first two variables separately. They are categorical variables, and it doesn't make sense to standardize them (you would also get an error). So, we will pull them out and add them to the formula using the `.join()` method of putting together strings in a list.
#
# Then, we are going to need to do the same thing, but we are going to have to surround each variable with `standardize(VARIABLE_NAME)`. The below piece of code will construct our formula:

# %%
ormula = 'Obama_margin_percent ~ ' + "+ ".join(variables[:2]) + "+ ".join(variables[35:]) + " + standardize(" + ") + standardize(".join(variables[2:34]) + ")"

# %%
variables.remove('Poverty_Unemploy_Interaction')

#Non-standardized variables (first two and last three now, since two variables are removed)
non_standardized = "+ ".join(variables[:2]) + "+ " + "+ ".join(variables[-3:])

# Standardized variables (from index 2 up to the non-standardized variables)
standardized = "+ standardize(" + ") + standardize(".join(variables[2:-3]) + ")"

# Combine all parts to form the complete formula
formula = 'Obama_margin_percent ~ ' + non_standardized + "+ " + standardized

print(formula)
# Out:
# Obama_margin_percent ~ Region+ ElectionType+ LandArea+ FarmArea+ YoungPopulationRatio+ + standardize(MalesPer100Females) + standardize(AgeBelow35) + standardize(Age35to65) + standardize(Age65andAbove) + standardize(White) + standardize(Black) + standardize(Asian) + standardize(AmericanIndian) + standardize(Hawaiian) + standardize(Hispanic) + standardize(HighSchool) + standardize(Bachelors) + standardize(Poverty) + standardize(IncomeAbove75K) + standardize(MedianIncome) + standardize(AverageIncome) + standardize(UnemployRate) + standardize(ManfEmploy) + standardize(SpeakingNonEnglish) + standardize(Medicare) + standardize(MedicareRate) + standardize(SocialSecurity) + standardize(SocialSecurityRate) + standardize(RetiredWorkers) + standardize(Disabilities) + standardize(DisabilitiesRate) + standardize(Homeowner) + standardize(SameHouse1995and2000) + standardize(Pop) + standardize(PopDensity)

# %% [markdown]
# We can then print the formula to make sure it did what we wanted.

# %% [markdown]
# It did, so we can make our new dataframes. Note that you certainly could have just typed in the formula by hand, but that would have been tedious and prone to mistyping variable names. You can also include interaction variables by just modifying the above formula.

# %% [markdown]
# We can now use the formula to construct our "design matrices" or the matrices that will be used for the regressions. I will name them `X_linear` for the set of independent variables we are using in our linear models and `y_linear` for the y variables.

# %%
y_linear, X_linear = dmatrices(formula, elect_df_smaller_train, return_type="dataframe")

# %% [markdown]
# We can see what `X_linear` ended up with:

# %%
X_linear
# Out:
#       Intercept  Region[T.Northeast]  Region[T.South]  Region[T.West]  \
# 1677        1.0                  0.0              1.0             0.0
# 594         1.0                  0.0              1.0             0.0
# 642         1.0                  0.0              1.0             0.0
# 1200        1.0                  0.0              1.0             0.0
# 81          1.0                  0.0              0.0             0.0
# ...         ...                  ...              ...             ...
# 868         1.0                  0.0              0.0             0.0
# 1377        1.0                  0.0              1.0             0.0
# 1536        1.0                  0.0              0.0             1.0
# 1577        1.0                  1.0              0.0             0.0
# 512         1.0                  0.0              0.0             1.0
#
#       ElectionType[T.Primary]  LandArea  FarmArea  YoungPopulationRatio  \
# 1677                      1.0     267.0      78.0              0.005331
# 594                       1.0     406.0      52.0              0.002987
# 642                       1.0     219.0      44.0              0.002976
# 1200                      1.0     658.0     326.0              0.004312
# 81                        0.0     468.0     229.0              0.000286
# ...                       ...       ...       ...                   ...
# 868                       0.0     720.0     273.0              0.001241
# 1377                      1.0     541.0      61.0              0.004475
# 1536                      1.0    2791.0    1074.0              0.000656
# 1577                      0.0    3255.0     152.0              0.001190
# 512                       0.0     550.0     274.0              0.015930
#
#       standardize(MalesPer100Females)  standardize(AgeBelow35)  \
# 1677                        -0.157112                -1.318521
# 594                         -0.469768                 0.129313
# 642                          0.301450                 0.780837
# 1200                        -0.303018                -0.124058
# 81                          -0.271753                 0.147410
# ...                               ...                      ...
# 868                          0.009637                -0.305037
# 1377                         0.478621                 0.328390
# 1536                         0.624527                 1.540950
# 1577                        -0.375971                -1.101346
# 512                         -0.021628                -1.155639
#
#       standardize(Age35to65)  standardize(Age65andAbove)  standardize(White)  \
# 1677                1.972336                    0.066582            0.507973
# 594                -0.575092                    0.315978           -1.652649
# 642                -0.054027                   -1.005819            0.077098
# 1200               -0.140872                    0.266099           -0.472424
# 81                  0.553882                   -0.681605            0.289413
# ...                      ...                         ...                 ...
# 868                -0.488248                    0.864648            0.826447
# 1377               -0.343508                   -0.157874           -0.228886
# 1536               -1.472482                   -0.831242            0.614131
# 1577                0.930206                    0.739950            0.532952
# 512                -0.546144                    2.036808            0.795224
#
#       standardize(Black)  standardize(Asian)  standardize(AmericanIndian)  \
# 1677           -0.383097           -0.420706                -2.926995e-01
# 594             1.833249           -0.338955                -2.683932e-01
# 642             0.067792           -0.298079                -2.926995e-01
# 1200           -0.599017           -0.379830                 3.426173e+00
# 81             -0.332293            0.233303                -2.683932e-01
# ...                  ...                 ...                          ...
# 868            -0.700626           -0.338955                -2.683932e-01
# 1377            0.398022           -0.420706                -2.440868e-01
# 1536           -0.656172           -0.052826                -1.023222e-03
# 1577           -0.700626           -0.338955                 7.767803e-01
# 512            -0.687924           -0.134577                 1.317650e-17
#
#       standardize(Hawaiian)  standardize(Hispanic)  standardize(HighSchool)  \
# 1677              -0.464422              -0.442051                -0.156514
# 594                0.311801              -0.292414                -0.848317
# 642               -0.464422              -0.488812                -0.238592
# 1200              -0.464422              -0.329823                -0.965571
# 81                -0.464422              -0.198891                 1.051210
# ...                     ...                    ...                      ...
# 868               -0.464422              -0.535574                 0.969131
# 1377              -0.464422              -0.470107                -1.399414
# 1536               0.311801               2.541333                -0.602082
# 1577              -0.464422              -0.516869                 0.300779
# 512                1.088024               0.661521                 0.230427
#
#       standardize(Bachelors)  standardize(Poverty)  \
# 1677                0.706687             -1.399435
# 594                 0.075640              0.931367
# 642                -0.352996             -0.615803
# 1200               -0.436341              0.509411
# 81                  0.944818             -0.254127
# ...                      ...                   ...
# 868                 0.039920             -1.218597
# 1377               -0.972136              1.413602
# 1536               -0.388715              0.529505
# 1577               -0.269650              0.770622
# 512                -0.424435             -0.455058
#
#       standardize(IncomeAbove75K)  standardize(MedianIncome)  \
# 1677                     1.335998                   1.116971
# 594                      0.517089                  -0.340774
# 642                      0.480961                   0.718449
# 1200                    -0.843744                  -1.038256
# 81                       0.721817                   0.817015
# ...                           ...                        ...
# 868                     -0.109135                   0.251347
# 1377                    -0.771487                  -0.716467
# 1536                    -0.169349                  -0.112206
# 1577                    -0.807616                  -0.919035
# 512                     -0.831701                  -0.905446
#
#       standardize(AverageIncome)  standardize(UnemployRate)  \
# 1677                    0.904296                  -1.476117
# 594                     0.056417                   0.777729
# 642                    -0.243072                  -0.036160
# 1200                   -0.794110                  -0.223980
# 81                      1.059824                  -0.537014
# ...                          ...                        ...
# 868                     0.377368                  -0.537014
# 1377                   -0.886786                  -0.537014
# 1536                   -0.679415                   1.215976
# 1577                   -0.323205                   1.716831
# 512                     0.031750                  -0.912655
#
#       standardize(ManfEmploy)  standardize(SpeakingNonEnglish)  \
# 1677            -1.003939e+00                        -0.520640
# 594             -4.664828e-01                        -0.458838
# 642              7.277537e-02                        -0.530940
# 1200             6.367941e-01                        -0.479439
# 81               2.315412e-01                        -0.252830
# ...                       ...                              ...
# 868              1.518093e-01                        -0.500039
# 1377            -1.081186e+00                        -0.489739
# 1536            -1.393121e-01                         2.085355
# 1577            -2.164124e-01                        -0.273431
# 512             -2.226055e-16                         0.128284
#
#       standardize(Medicare)  standardize(MedicareRate)  \
# 1677              -0.294441                   0.786197
# 594               -0.266044                   0.292426
# 642               -0.281042                  -0.657090
# 1200              -0.284668                   0.491214
# 81                 0.142947                  -0.554308
# ...                     ...                        ...
# 868               -0.177964                   0.645200
# 1377              -0.288049                   0.090061
# 1536              -0.099575                  -0.668009
# 1577              -0.172555                   0.989691
# 512               -0.313086                   1.546901
#
#       standardize(SocialSecurity)  standardize(SocialSecurityRate)  \
# 1677                    -0.319977                         0.091932
# 594                     -0.277646                         0.669039
# 642                     -0.296665                        -0.674390
# 1200                    -0.300079                         0.895896
# 81                       0.168485                        -0.702974
# ...                           ...                              ...
# 868                     -0.187717                         0.715538
# 1377                    -0.309150                        -0.131705
# 1536                    -0.103056                        -0.895611
# 1577                    -0.181768                         1.138253
# 512                     -0.335582                         1.432946
#
#       standardize(RetiredWorkers)  standardize(Disabilities)  \
# 1677                    -0.308114                  -0.197891
# 594                     -0.269523                  -0.167923
# 642                     -0.287928                  -0.185359
# 1200                    -0.297872                  -0.174461
# 81                       0.173526                   0.005620
# ...                           ...                        ...
# 868                     -0.169930                  -0.172418
# 1377                    -0.308411                  -0.172350
# 1536                    -0.097944                  -0.086192
# 1577                    -0.182398                  -0.117862
# 512                     -0.324737                  -0.201433
#
#       standardize(DisabilitiesRate)  standardize(Homeowner)  \
# 1677                      -0.768164                0.200764
# 594                        0.498135                0.348283
# 642                       -0.513338                0.987531
# 1200                       1.022246                0.040952
# 81                        -0.401889               -0.364724
# ...                             ...                     ...
# 868                       -0.751296                0.446629
# 1377                       1.124659                0.692494
# 1536                      -0.268753               -0.844161
# 1577                       0.731877                0.508095
# 512                       -0.531411               -0.069687
#
#       standardize(SameHouse1995and2000)  standardize(Pop)  \
# 1677                           1.088300         -0.265316
# 594                           -0.223162         -0.245378
# 642                           -0.087959         -0.242346
# 1200                          -0.209641         -0.257579
# 81                            -0.547647          0.106632
# ...                                 ...               ...
# 868                            0.358208         -0.197674
# 1377                           0.331168         -0.257150
# 1536                          -1.088456         -0.084846
# 1577                           1.169422         -0.202889
# 512                            0.817896         -0.276650
#
#       standardize(PopDensity)
# 1677                -0.137642
# 594                 -0.132594
# 642                 -0.118266
# 1200                -0.141836
# 81                  -0.010239
# ...                       ...
# 868                 -0.126420
# 1377                -0.140322
# 1536                -0.136167
# 1577                -0.143079
# 512                 -0.146379
#
# [1302 rows x 38 columns]

# %% [markdown]
# As you can see, there is an `Intercept` column (of all one's), a set of columns dummy encoding the region and election type, and columns that correspond to the standardized variables we put in.

# %% [markdown]
# `y_linear` is just the Obama percent margin.

# %%
y_linear
# Out:
#       Obama_margin_percent
# 1677              0.199231
# 594               0.399012
# 642              -0.020424
# 1200             -0.386296
# 81                0.188571
# ...                    ...
# 868               0.047990
# 1377             -0.142698
# 1536             -0.085749
# 1577              0.272727
# 512              -0.333333
#
# [1302 rows x 1 columns]

# %% [markdown]
# Now we have to start building our Lasso model. We start with getting a `Lasso` object set up with all of the parameters. We choose `alpha`, which is our regularization parameter, and we choose `max_iter` which is a parameter that just tells the model how long it can train for (you don't need to worry about the details here right now).

# %%
lm_lasso = Lasso(alpha = 1, max_iter=1000000)

# %% [markdown]
# Once we have our lasso object, we can fit it to our data. This is just like the imputer we used above.

# %%
lm_lasso.fit(X_linear, y_linear)
# Out:
# Lasso(alpha=1, max_iter=1000000)

# %% [markdown]
# In order to predict on our validation data, we have to convert our validation data into the same format as our training data (using the exact same transformations and dummy codings). We can do that with the `build_design_matrices` function from `patsy`. We give it the `design_info` of our earlier dataframe `X_linear`, and we give it our new data. Note that at the end we access it with `[0]`. This is because it returns a list of dataframes (though the list only has one element in it), so we ask for the first element in that list.

# %%
X_validation_linear = build_design_matrices([X_linear.design_info], elect_df_validation, return_type="dataframe")[0]

# %% [markdown]
# We can see it worked!

# %%
X_validation_linear
# Out:
#       Intercept  Region[T.Northeast]  Region[T.South]  Region[T.West]  \
# 1700        1.0                  0.0              1.0             0.0
# 569         1.0                  0.0              1.0             0.0
# 564         1.0                  0.0              1.0             0.0
# 538         1.0                  0.0              1.0             0.0
# 992         1.0                  0.0              0.0             0.0
# ...         ...                  ...              ...             ...
# 921         1.0                  0.0              0.0             0.0
# 1449        1.0                  0.0              0.0             0.0
# 1062        1.0                  1.0              0.0             0.0
# 1172        1.0                  0.0              1.0             0.0
# 111         1.0                  0.0              0.0             1.0
#
#       ElectionType[T.Primary]  LandArea     FarmArea  YoungPopulationRatio  \
# 1700                      1.0      13.0   263.877221              0.002366
# 569                       1.0     174.0    28.000000              0.003000
# 564                       1.0     308.0    23.000000              0.000457
# 538                       1.0     458.0   126.000000              0.002894
# 992                       1.0     621.0   340.000000              0.003265
# ...                       ...       ...          ...                   ...
# 921                       0.0     432.0   282.000000              0.001314
# 1449                      1.0     419.0   244.000000              0.004618
# 1062                      1.0     665.0    47.000000              0.000069
# 1172                      1.0     943.0   458.000000              0.001266
# 111                       0.0   17203.0  2472.000000              0.001116
#
#       standardize(MalesPer100Females)  standardize(AgeBelow35)  \
# 1700                        -1.751657                -0.775583
# 569                         -0.219644                 0.545565
# 564                         -0.396815                 0.563662
# 538                         -0.250909                 0.509369
# 992                         -0.980439                -0.666996
# ...                               ...                      ...
# 921                         -0.063316                 0.346487
# 1449                         0.916339                 0.183606
# 1062                        -0.428081                -0.305037
# 1172                        -0.230065                 0.527467
# 111                          0.801699                 1.251383
#
#       standardize(Age35to65)  standardize(Age65andAbove)  standardize(White)  \
# 1700               -0.748781                    1.712594            0.451772
# 569                -0.198768                   -0.556907            0.764001
# 564                 0.727570                   -1.429792           -0.278843
# 538                -0.372456                   -0.407270            0.164522
# 992                -0.285612                    1.163923            0.801468
# ...                      ...                         ...                 ...
# 921                 0.003869                   -0.457149            0.689066
# 1449               -0.922469                    0.540434            0.807713
# 1062                1.161791                   -0.581847            0.033386
# 1172               -0.806677                   -0.033176           -0.241375
# 111                 0.148609                   -1.878704            0.383082
#
#       standardize(Black)  standardize(Asian)  standardize(AmericanIndian)  \
# 1700           -0.351345           -0.216328                    -0.292700
# 569            -0.649821           -0.338955                    -0.244087
# 564             0.163051            0.887312                    -0.268393
# 538            -0.027466           -0.338955                    -0.292700
# 992            -0.675223           -0.420706                    -0.244087
# ...                  ...                 ...                          ...
# 921            -0.586315           -0.175452                    -0.317006
# 1449           -0.719677           -0.379830                    -0.244087
# 1062           -0.211632            1.500445                    -0.292700
# 1172           -0.624419           -0.257204                     2.648370
# 111            -0.668873           -0.134577                     1.019844
#
#       standardize(Hawaiian)  standardize(Hispanic)  standardize(HighSchool)  \
# 1700              -0.464422              -0.498164                -0.578631
# 569               -0.464422              -0.516869                -1.211806
# 564                0.311801              -0.348528                 1.238817
# 538               -0.464422              -0.357880                -1.329061
# 992               -0.464422              -0.535574                 0.312505
# ...                     ...                    ...                      ...
# 921               -0.464422              -0.208243                 1.086386
# 1449               4.969139               2.354287                -0.625533
# 1062              -0.464422               0.091030                 1.238817
# 1172              -0.464422              -0.273709                -0.285494
# 111                0.311801               1.409705                 0.206976
#
#       standardize(Bachelors)  standardize(Poverty)  \
# 1700                0.004201              0.650063
# 569                -0.722098             -0.254127
# 564                 1.790182             -1.359248
# 538                -0.900697              0.730436
# 992                -0.734005              0.208015
# ...                      ...                   ...
# 921                 0.373304             -1.319062
# 1449               -0.650659             -0.816734
# 1062                2.099752             -1.540086
# 1172                0.111360              0.609877
# 111                -0.257743             -0.977479
#
#       standardize(IncomeAbove75K)  standardize(MedianIncome)  \
# 1700                    -0.663102                  -0.872107
# 569                     -0.277734                  -0.130234
# 564                      2.034479                   2.232996
# 538                     -0.663102                  -0.550771
# 992                     -0.891915                  -0.733861
# ...                           ...                        ...
# 921                      0.468918                   1.035527
# 1449                    -0.386118                  -0.014546
# 1062                     3.347141                   3.113840
# 1172                    -0.747402                  -0.970130
# 111                      0.709774                   1.283301
#
#       standardize(AverageIncome)  standardize(UnemployRate)  \
# 1700                6.560254e-17                   0.026447
# 569                -5.917561e-01                  -0.411801
# 564                 1.102469e+00                  -0.349194
# 538                -4.975473e-01                  -0.286587
# 992                -4.561568e-01                   1.278583
# ...                          ...                        ...
# 921                 5.894768e-01                  -0.411801
# 1449               -7.360792e-02                  -1.476117
# 1062                2.939539e+00                  -0.349194
# 1172               -4.288418e-01                  -0.662228
# 111                 3.782039e-01                  -0.724835
#
#       standardize(ManfEmploy)  standardize(SpeakingNonEnglish)  \
# 1700            -2.226055e-16                        -0.572142
# 569              1.029992e+00                        -0.489739
# 564             -3.679372e-01                         0.014979
# 538              2.290338e+00                        -0.417636
# 992              5.348668e-01                        -0.489739
# ...                       ...                              ...
# 921              1.902549e+00                        -0.108625
# 1449            -2.226055e-16                         2.116256
# 1062            -1.021779e+00                         0.684504
# 1172            -4.565081e-01                        -0.469138
# 111             -1.330930e+00                         1.230424
#
#       standardize(Medicare)  standardize(MedicareRate)  \
# 1700              -0.208615                   3.002425
# 569               -0.271412                  -0.091409
# 564               -0.102812                  -1.254397
# 538               -0.269015                  -0.085009
# 992               -0.264077                   1.116946
# ...                     ...                        ...
# 921               -0.219289                  -0.483715
# 1449              -0.250657                   3.424285
# 1062               1.535019                  -0.542825
# 1172              -0.186692                   0.158582
# 111               -0.246621                  -1.626561
#
#       standardize(SocialSecurity)  standardize(SocialSecurityRate)  \
# 1700                    -0.254335                         1.612499
# 569                     -0.289448                        -0.191690
# 564                     -0.090279                        -1.448161
# 538                     -0.284083                        -0.013344
# 992                     -0.287985                         0.770491
# ...                           ...                              ...
# 921                     -0.235022                        -0.731558
# 1449                    -0.315880                        -0.748869
# 1062                     1.608121                        -0.843678
# 1172                    -0.197178                         0.122126
# 111                     -0.255212                        -1.896843
#
#       standardize(RetiredWorkers)  standardize(Disabilities)  \
# 1700                    -0.254532                  -0.147626
# 569                     -0.288967                  -0.179365
# 564                     -0.095866                  -0.132983
# 538                     -0.284069                  -0.158524
# 992                     -0.279171                  -0.184065
# ...                           ...                        ...
# 921                     -0.219504                  -0.181817
# 1449                    -0.306184                  -0.199662
# 1062                     1.690726                   0.259327
# 1172                    -0.205255                  -0.114185
# 111                     -0.251119                  -0.173372
#
#       standardize(DisabilitiesRate)  standardize(Homeowner)  \
# 1700                       1.339122               -1.040852
# 569                       -0.177184                0.827719
# 564                       -0.947085                1.048997
# 538                        0.871037                0.225351
# 992                       -0.188630                0.409749
# ...                             ...                     ...
# 921                       -0.997689                0.803133
# 1449                      -1.157332                0.200764
# 1062                      -0.910337                0.127005
# 1172                       0.553559               -0.512243
# 111                       -0.954314               -0.450777
#
#       standardize(SameHouse1995and2000)  standardize(Pop)  \
# 1700                           0.033723         -0.240683
# 569                            0.236526         -0.243705
# 564                           -0.642289         -0.026751
# 538                            0.250046         -0.242454
# 992                            0.114844         -0.251765
# ...                                 ...               ...
# 921                           -0.074439         -0.195870
# 1449                           0.439329         -0.258352
# 1062                           0.412289          1.237815
# 1172                          -0.818052         -0.190667
# 111                           -1.412941         -0.169801
#
#       standardize(PopDensity)
# 1700                 0.378534
# 569                 -0.111898
# 564                 -0.004997
# 538                 -0.133759
# 992                 -0.140089
# ...                       ...
# 921                 -0.115392
# 1449                -0.138613
# 1062                 0.374573
# 1172                -0.131740
# 111                 -0.147078
#
# [435 rows x 38 columns]

# %% [markdown]
# Now let's predict on our new dataset.

# %%
lm_lass_pred = lm_lasso.predict(X_validation_linear)

# %% [markdown]
# How did we do?

# %%
accuracy(lm_lass_pred, elect_df_validation["Obama_margin_percent"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_14a36">
#   <thead>
#     <tr>
#       <th id="T_14a36_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_14a36_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_14a36_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_14a36_row0_col0" class="data row0 col0" >0.311624</td>
#       <td id="T_14a36_row0_col1" class="data row0 col1" >0.252613</td>
#       <td id="T_14a36_row0_col2" class="data row0 col2" >-391.113657</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Eh, not too well. Maybe we chose the wrong `alpha`. Let's take a closer look at what `alpha` is actually doing. We are going to try a bunch of different `alpha`s and see how the regression coefficients change as we change the `alpha`s. The details of what are happening in the next few cells are not important. The graph that comes out is.

# %% [markdown]
# The first thing we're going to do is get a list of `alpha`s to try. The below code will give us a list of `alpha` that range from `1*10^-5` to `1` on a log scale. This means that the space between `alpha`s will not be even, but they will be closer together the smaller `alpha` is.

# %%
alphas = np.logspace(-5,0, 20)

# %%
alphas
# Out:
# array([1.00000000e-05, 1.83298071e-05, 3.35981829e-05, 6.15848211e-05,
#        1.12883789e-04, 2.06913808e-04, 3.79269019e-04, 6.95192796e-04,
#        1.27427499e-03, 2.33572147e-03, 4.28133240e-03, 7.84759970e-03,
#        1.43844989e-02, 2.63665090e-02, 4.83293024e-02, 8.85866790e-02,
#        1.62377674e-01, 2.97635144e-01, 5.45559478e-01, 1.00000000e+00])

# %% [markdown]
# Now we will build models using each of those alphas using this loop.

# %%
# %%time
coefs = []
for a in alphas:
    lm_lasso = Lasso(alpha=a, max_iter=1000000)
    lm_lasso.fit(X_linear, y_linear)
    coefs.append(lm_lasso.coef_)
# Out:
# CPU times: user 1.32 s, sys: 2.36 s, total: 3.68 s
# Wall time: 1.82 s

# %% [markdown]
# Finally, we will plot the coefficients for the independent variables from each of our models as the `alpha` changes.
#
# NOTE: This plot is not a necessary part of the analysis. We are plotting it because it is instructional to see how the coefficients of the regression model change as we change alpha.

# %%
ax = plt.gca()

for i in range(len(coefs[0])):
    ax.plot(alphas, [coef[i] for coef in coefs], label=X_linear.columns[i])
ax.set_xscale('log')
plt.xlabel('alpha')
plt.ylabel('coefficient value')
plt.title('Lasso coefficients as a function of the regularization')
plt.axis('tight')
plt.legend(loc='right', bbox_to_anchor=(1.35, 0.5), shadow=True, ncol=1)
plt.show()

# %% [markdown]
# As we increase `alpha`, the variables are "turning off". We can see this because the lines representing the coefficients start to go to `0`. If the coefficient of a variable is `0`, then it might as well not be in the regression at all! The higher the `alpha`, the fewer the variables are that have a non-zero regression coefficient. It is trying to find only the most impactful variables.
#
# The question naturally arises, how does one actually choose the `alpha` here. We do this with out of sample testing! However, plugging and chugging through a bunch of `alpha` values is boring, and we want to let the computer do the boring work. Moreover, there is something better than just out of sample testing.
#
# If our training set is small, a regression model's performance will be sensitive to the rows we (randomly) chose to put in the one validation set. To combat this sensitivity, statisticians employ a technique called K-fold cross-validation. They often use 5-fold cross-validation. See ISL pp. 198-206, section 5.1-5.1.4, for more information on this topic.
#
# Suppose we use 5-fold cross-validation to find the best setting for the parameter lambda in the lasso. Below are the steps in the procedure.
#
# Step 1: Split the training set randomly up into 5 equal "folds": Fold 1, Fold 2, Fold 3, Fold 4, and Fold 5.
#
# Step 2: Use Folds 1, 2, 3, and 4 as the smaller training set and Fold 5 as the validation set. For each level of the model's parameter, record the average prediction errors on the Fold 5 validation set.
#
# Step 3: Use Folds 1, 2, 3, and 5 as the smaller training set and Fold 4 as the validation set. For each level of the model's parameter, record the average prediction errors on the Fold 4 validation set.
#
# Step 4: Use Folds 1, 2, 4, and 5 as the smaller training set and Fold 3 as the validation set. For each level of the model's parameter, record the average prediction errors on the Fold 3 validation set.
#
# Step 5: Use Folds 1, 3, 4, and 5 as the smaller training set and Fold 2 as the validation set. For each level of the model's parameter, record the average prediction errors on the Fold 2 validation set.
#
# Step 6: Use Folds 2, 3, 4, and 5 as the smaller training set and Fold 1 as the validation set. For each level of the model's parameter, record the average prediction errors on the Fold 1 validation set.
#
# Step 7: For each level of the model's parameter, average the five folds' average prediction errors for each level of the model's tuning parameter. Select the tuning parameter level with the lowest overall average.

# %% [markdown]
# It would be a giant pain to do all of this manually, so instead, we will use a very useful function called `GridSearchCV`. This automatically tries a bunch of parameter values (`alpha` in this case), and it runs 4-fold validation on it. Below we set it up with a Lasso model, and we give it the list of `alpha`s we looped through above.
#
# Running `fit` on this might take a little bit of time (up to 10 minutes).

# %%
gs_lasso = GridSearchCV(Lasso(max_iter=1000000), {"alpha": alphas}, scoring='neg_mean_squared_error', cv=4)

# %%
# %%time
gs_lasso.fit(X_linear, y_linear)
# Out:
# CPU times: user 6.24 s, sys: 10.3 s, total: 16.5 s
# Wall time: 8.24 s
# GridSearchCV(cv=4, estimator=Lasso(max_iter=1000000),
#              param_grid={'alpha': array([1.00000000e-05, 1.83298071e-05, 3.35981829e-05, 6.15848211e-05,
#        1.12883789e-04, 2.06913808e-04, 3.79269019e-04, 6.95192796e-04,
#        1.27427499e-03, 2.33572147e-03, 4.28133240e-03, 7.84759970e-03,
#        1.43844989e-02, 2.63665090e-02, 4.83293024e-02, 8.85866790e-02,
#        1.62377674e-01, 2.97635144e-01, 5.45559478e-01, 1.00000000e+00])},
#              scoring='neg_mean_squared_error')

# %% [markdown]
# What is the best `alpha`?

# %%
gs_lasso.best_params_['alpha']
# Out:
# 0.0006951927961775606

# %% [markdown]
# Let's put this on our plot.

# %%
ax = plt.gca()

for i in range(len(coefs[0])):
    ax.plot(alphas, [coef[i] for coef in coefs], label=X_linear.columns[i])
ax.set_xscale('log')
plt.xlabel('alpha')
plt.ylabel('coefficient value')
plt.title('Lasso coefficients as a function of the regularization')
plt.axis('tight')
plt.legend(loc='right', bbox_to_anchor=(1.35, 0.5), shadow=True, ncol=1)
plt.axvline(x=gs_lasso.best_params_['alpha'], linestyle='--', color='tab:red')
plt.show()

# %% [markdown]
# Our initial guess of `alpha = 1` was way off! Let's see how the optimal `alpha` does. By building our model again with the optimal `alpha`.

# %%
lm_lasso_optimized = Lasso(alpha = gs_lasso.best_params_['alpha'], max_iter=1000000)
lm_lasso_optimized.fit(X_linear,y_linear)
# Out:
# Lasso(alpha=0.0006951927961775606, max_iter=1000000)

# %% [markdown]
# Make a prediction using the regularized linear regression with an optimal lambda.

# %%
lm_lasso_optimized_pred = lm_lasso_optimized.predict(X_validation_linear)

# %% [markdown]
# Note that we could have also called `predict` straight on the `GridSearchCV` object, and it will automatically predict with the best model it found like so.

# %%
gs_lasso_pred = gs_lasso.predict(X_validation_linear)

# %%
print("Accuracy of the lm_lasso_optimized model:")
accuracy(lm_lasso_optimized_pred, elect_df_validation["Obama_margin_percent"])
print("Accuracy of the gs_lasso model:")
accuracy(gs_lasso_pred, elect_df_validation["Obama_margin_percent"])
# Out:
# Accuracy of the lm_lasso_optimized model:
# <style type="text/css">
# </style>
# <table id="T_f0020">
#   <thead>
#     <tr>
#       <th id="T_f0020_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_f0020_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f0020_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f0020_row0_col0" class="data row0 col0" >0.169337</td>
#       <td id="T_f0020_row0_col1" class="data row0 col1" >0.127133</td>
#       <td id="T_f0020_row0_col2" class="data row0 col2" >0.574077</td>
#     </tr>
#   </tbody>
# </table>
# Accuracy of the gs_lasso model:
# <style type="text/css">
# </style>
# <table id="T_d1349">
#   <thead>
#     <tr>
#       <th id="T_d1349_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_d1349_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d1349_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d1349_row0_col0" class="data row0 col0" >0.169337</td>
#       <td id="T_d1349_row0_col1" class="data row0 col1" >0.127133</td>
#       <td id="T_d1349_row0_col2" class="data row0 col2" >0.574077</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That's better! Also, we see that both ways of predicting give us the exact same outcome, so they are both valid ways to do the final prediction.

# %% [markdown]
# There is one more thing we can do; we can look at the coefficients to tell us what variables are the most important. Since we standardized all of the variables, then what a coefficient means is exactly how much does the dependent variable `Obama_margin_percent` change for one standard deviation change in the independent variable. The independent variable with the highest coefficient means it has the highest impact on the predicted `Obama_margin_percent`. Note that it is the _absolute value of the coefficient_ not the size directly. A very negative coefficient is just as meaningful as a very postive coefficient (though obviously it affects the dependent variable in the opposite way).

# %% [markdown]
# This next piece of code will plot the coefficients.

# %%
def get_linear_importances(model, data):
    # This section is to handle both LASSO and ridge.
    if len(model.coef_) == 1:
        coefficients = np.concatenate((model.coef_[0], [model.intercept_]))
    else:
        coefficients = np.concatenate((model.coef_, model.intercept_))
    coef_df = pd.DataFrame({'Importance': coefficients}, index=data.columns.append(pd.Index(["Model Intercept"])))
    return coef_df.reindex(coef_df.Importance.abs().sort_values(ascending=False).index)

# %%
get_linear_importances(lm_lasso_optimized, X_linear)
# Out:
#                                            Importance
# Model Intercept                              0.259448
# standardize(White)                          -0.251801
# Region[T.South]                             -0.235805
# Region[T.Northeast]                         -0.199436
# Region[T.West]                               0.130718
# standardize(Bachelors)                       0.125496
# ElectionType[T.Primary]                     -0.117522
# standardize(Asian)                          -0.064189
# standardize(Black)                           0.060686
# standardize(SocialSecurity)                 -0.054753
# standardize(AmericanIndian)                 -0.052838
# standardize(DisabilitiesRate)               -0.051671
# standardize(Poverty)                        -0.049128
# standardize(MedianIncome)                   -0.038834
# standardize(SameHouse1995and2000)            0.033388
# standardize(Disabilities)                    0.032013
# standardize(Homeowner)                       0.018993
# standardize(AgeBelow35)                      0.018457
# standardize(UnemployRate)                    0.017985
# standardize(FarmArea)                       -0.017831
# standardize(MedicareRate)                    0.017774
# standardize(AverageIncome)                  -0.015813
# standardize(Hawaiian)                       -0.014440
# standardize(PopDensity)                     -0.012820
# standardize(Age65andAbove)                  -0.010210
# Log_PopDensity                               0.009802
# standardize(LandArea)                        0.008729
# standardize(IncomeAbove75K)                 -0.008081
# standardize(SocialSecurityRate)             -0.007311
# standardize(ManfEmploy)                     -0.006856
# standardize(SpeakingNonEnglish)              0.006235
# standardize(MalesPer100Females)              0.002568
# Poverty_Unemploy_Interaction                -0.001865
# standardize(Hispanic)                       -0.000052
# High_Hispanic                                0.000000
# standardize(Medicare)                       -0.000000
# standardize(RetiredWorkers)                 -0.000000
# standardize(Age35to65)                      -0.000000
# Normalized_Income                           -0.000000
# standardize(HighSchool)                     -0.000000
# standardize(Pop)                             0.000000
# YoungPopulationRatio                        -0.000000
# standardize(Poverty_Unemploy_Interaction)   -0.000000
# Intercept                                    0.000000

# %% [markdown]
# The above is consistent with the size of the coefficients that we saw from our plot, but it gives us a very clear way to understand what factors are important for predicting an Obama victory. Note that we see the intercept in their twice. This is because our model has an intercept column, and the LASSO automatically fits an intercept. Since the intercept column in our model is redundant, the LASSO gets rid of it by setting the coefficient to `0`.

# %% [markdown]
# ## Ridge Regression

# %% [markdown]
# Now let's try a ridge regression. This is another regularized regression techique, and we will use nearly the exact same code as before. Here, we will use the same `X_linear`, `y_linear`, and `X_validation_linear` that we used above. We certainly could have chosen different variables for this model as well, though.

# %%
alphas = np.logspace(-2,6, 20)

# %%
alphas
# Out:
# array([1.00000000e-02, 2.63665090e-02, 6.95192796e-02, 1.83298071e-01,
#        4.83293024e-01, 1.27427499e+00, 3.35981829e+00, 8.85866790e+00,
#        2.33572147e+01, 6.15848211e+01, 1.62377674e+02, 4.28133240e+02,
#        1.12883789e+03, 2.97635144e+03, 7.84759970e+03, 2.06913808e+04,
#        5.45559478e+04, 1.43844989e+05, 3.79269019e+05, 1.00000000e+06])

# %% [markdown]
# You might get a few warnings below. Ignore them.

# %%
# %%time
coefs = []
for a in alphas:
    lm_ridge = Ridge(alpha=a, fit_intercept=False, max_iter=1000000)
    lm_ridge.fit(X_linear, y_linear)
    coefs.append(lm_ridge.coef_[0])
# Out:
# CPU times: user 68.8 ms, sys: 151 ms, total: 220 ms
# Wall time: 62 ms

# %%
gs_ridge = GridSearchCV(Ridge(fit_intercept=False, max_iter=1000000), {"alpha": alphas}, scoring='neg_mean_squared_error', cv=5)

# %%
# %%time
gs_ridge.fit(X_linear, y_linear)
# Out:
# CPU times: user 824 ms, sys: 1.31 s, total: 2.14 s
# Wall time: 1.04 s
# GridSearchCV(cv=5, estimator=Ridge(fit_intercept=False, max_iter=1000000),
#              param_grid={'alpha': array([1.00000000e-02, 2.63665090e-02, 6.95192796e-02, 1.83298071e-01,
#        4.83293024e-01, 1.27427499e+00, 3.35981829e+00, 8.85866790e+00,
#        2.33572147e+01, 6.15848211e+01, 1.62377674e+02, 4.28133240e+02,
#        1.12883789e+03, 2.97635144e+03, 7.84759970e+03, 2.06913808e+04,
#        5.45559478e+04, 1.43844989e+05, 3.79269019e+05, 1.00000000e+06])},
#              scoring='neg_mean_squared_error')

# %%
ax = plt.gca()


for i in range(len(coefs[0])):
    ax.plot(alphas, [coef[i] for coef in coefs], label=X_linear.columns[i])
ax.set_xscale('log')
plt.xlabel('alpha')
plt.ylabel('coefficient value')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.legend(loc='right', bbox_to_anchor=(1.35, 0.5), shadow=True, ncol=1)
plt.axvline(x=gs_ridge.best_params_['alpha'], linestyle='--', color='tab:red')
plt.show()

# %% [markdown]
# The way that the ridge regression regularizes is a little different. What do you think are the advantages/disadvantages between the ridge regression and the Lasso?

# %%
gs_ridge_pred = gs_ridge.predict(X_validation_linear)

# %%
accuracy(gs_ridge_pred, elect_df_validation["Obama_margin_percent"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_52f13">
#   <thead>
#     <tr>
#       <th id="T_52f13_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_52f13_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_52f13_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52f13_row0_col0" class="data row0 col0" >0.169688</td>
#       <td id="T_52f13_row0_col1" class="data row0 col1" >0.128107</td>
#       <td id="T_52f13_row0_col2" class="data row0 col2" >0.574124</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now we can look at the coefficients, but if we want to use our `gs_ridge` model directly, we have to get out the actual best model that it found. We can do that by looking at the value `gs_ridge.best_estimator_`.

# %%
get_linear_importances(gs_ridge.best_estimator_, X_linear)
# Out:
#                                            Importance
# standardize(White)                          -0.239548
# Region[T.South]                             -0.234626
# Region[T.Northeast]                         -0.200784
# Region[T.West]                               0.143034
# standardize(Bachelors)                       0.129651
# standardize(SocialSecurity)                 -0.118372
# ElectionType[T.Primary]                     -0.116807
# standardize(Poverty_Unemploy_Interaction)   -0.091659
# standardize(Black)                           0.074084
# standardize(Asian)                          -0.067406
# standardize(Poverty)                        -0.062959
# Intercept                                    0.059301
# standardize(MedianIncome)                   -0.055322
# standardize(AmericanIndian)                 -0.052696
# standardize(DisabilitiesRate)               -0.051015
# standardize(Pop)                             0.039939
# standardize(SameHouse1995and2000)            0.036219
# standardize(RetiredWorkers)                  0.034395
# standardize(Disabilities)                    0.030726
# standardize(Homeowner)                       0.024536
# standardize(SpeakingNonEnglish)              0.021682
# standardize(MedicareRate)                    0.021154
# High_Hispanic                                0.020366
# standardize(Age65andAbove)                  -0.019038
# standardize(Hispanic)                       -0.018473
# Log_PopDensity                               0.018342
# Normalized_Income                            0.017847
# standardize(FarmArea)                       -0.017305
# standardize(UnemployRate)                    0.016350
# standardize(Hawaiian)                       -0.014832
# standardize(PopDensity)                     -0.014813
# standardize(AverageIncome)                  -0.013900
# standardize(IncomeAbove75K)                 -0.012412
# standardize(LandArea)                        0.011760
# standardize(Medicare)                       -0.011712
# standardize(SocialSecurityRate)             -0.010537
# standardize(AgeBelow35)                      0.010318
# standardize(ManfEmploy)                     -0.008470
# YoungPopulationRatio                        -0.005345
# standardize(Age35to65)                      -0.004976
# standardize(MalesPer100Females)              0.004788
# standardize(HighSchool)                      0.001454
# Poverty_Unemploy_Interaction                 0.000408
# Model Intercept                              0.000000

# %% [markdown]
# Compare the accuracy on the validation set of all three models fit above.

# %%
print("lm_1 accuracy:")
accuracy(lm_1_pred, elect_df_validation["Obama_margin_percent"])
print("gs_lasso accuracy:")
accuracy(gs_lasso_pred, elect_df_validation["Obama_margin_percent"])
print("gs_ridge accuracy:")
accuracy(gs_ridge_pred, elect_df_validation["Obama_margin_percent"])
# Out:
# lm_1 accuracy:
# <style type="text/css">
# </style>
# <table id="T_f67bd">
#   <thead>
#     <tr>
#       <th id="T_f67bd_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_f67bd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f67bd_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f67bd_row0_col0" class="data row0 col0" >0.187891</td>
#       <td id="T_f67bd_row0_col1" class="data row0 col1" >0.143283</td>
#       <td id="T_f67bd_row0_col2" class="data row0 col2" >0.413451</td>
#     </tr>
#   </tbody>
# </table>
# gs_lasso accuracy:
# <style type="text/css">
# </style>
# <table id="T_5a46c">
#   <thead>
#     <tr>
#       <th id="T_5a46c_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_5a46c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5a46c_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5a46c_row0_col0" class="data row0 col0" >0.170317</td>
#       <td id="T_5a46c_row0_col1" class="data row0 col1" >0.128637</td>
#       <td id="T_5a46c_row0_col2" class="data row0 col2" >0.561096</td>
#     </tr>
#   </tbody>
# </table>
# gs_ridge accuracy:
# <style type="text/css">
# </style>
# <table id="T_4c6bd">
#   <thead>
#     <tr>
#       <th id="T_4c6bd_level0_col0" class="col_heading level0 col0" >RMSE</th>
#       <th id="T_4c6bd_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4c6bd_level0_col2" class="col_heading level0 col2" >R^2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4c6bd_row0_col0" class="data row0 col0" >0.169688</td>
#       <td id="T_4c6bd_row0_col1" class="data row0 col1" >0.128107</td>
#       <td id="T_4c6bd_row0_col2" class="data row0 col2" >0.574124</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Competition submission (for the second day on this case)

# %% [markdown]
# Now you will need to use your best model to predict on the test set. To do this, you will need to take the following steps:
# 1. Decide on which model, which parameters for the model, and what data to train the model based on your analysis above.
# 2. Go back and fit your model on the entire `elect_df_train` dataframe (not just the `elect_df_smaller_train` dataframe).
# 3. Transform your `elect_df_test` dataframe in the same way that you did the `elect_df_train` dataframe.
# 4. Predict on your transformed `elect_df_test` dataframe using the `predict()` method of your chosen model.
# 5. Save the predictions in a variable called `bm_all_fit_pred` (it should have 1131 rows and 1 column).
# 6. Run the code below to generate your submission csv (change `TeamX` to your team).
#
# A useful guiding principle when coming up with your final prediction is that you should copy your code above (maybe even to a new notebook) and everywhere you see `smaller_train` replace it with `train` and everywhere you see `validation` replace it with `test`. This will include potentially redoing imputation and feature engineering steps as well. You should not be doing any _model selection_ during this process, but just _refitting_ the model you selected with the full training data set and then predicting on the testing set (just like you predicted on the validation set). However, you will not be able to test your model's accuracy using the `accuracy` function because you do not have the realizations for the test set.

# %% [markdown]
# The below code will combine the row numbers from the original `elect_df_test` dataset and the predictions from `bm_all_fit_pred` into a new dataframe called `submission_df`. NOTE: Until you have a variable called `bm_all_fit_pred` with your predictions in it, you will receive an error.

# %%
submission_df = pd.DataFrame(bm_all_fit_pred, index=elect_df_test.index, columns=['Obama_margin_percent'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 submission_df = pd.DataFrame(bm_all_fit_pred, index=elect_df_test.index, columns=['Obama_margin_percent'])
#
# NameError: name 'bm_all_fit_pred' is not defined

# %% [markdown]
# You now should have a dataframe that has indices equal to the indices for `elect_df_test` going from `1737` to `2867` and a column titled `Obama_margin_percent`. Check to make sure this is the case:

# %%
submission_df

# %% [markdown]
#  This can then be written to a submission file that is in the correct format for uploading to Kaggle.

# %%
submission_df.to_csv("ObamaSubmissionTeamX.csv", index_label='Row')

# %% [markdown]
# # Sample Code for Getting Final Predictions

# %% [markdown]
# Below is sample code (not intended to be used for your actual submission) walking you through the above steps for the case where we choose the untuned decision tree. Note that the major difference is that we are using the entire training data set to create our design matrices (and not just `elect_df_smaller_train`). Then we are predicting on the test set. We cannot check our accuracy on the test set because we don't have the realizations yet.

# %% [markdown]
# However, before we can even train our model, we need to make sure that we re-impute using an imputer trained on the full training set (remember before we just trained the imputer on `elect_df_smaller_train`). So, we create a new imputer:

# %%
final_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
final_imputer.fit(elect_df_train.loc[:, "MalesPer100Females":"FarmArea"])

# %% [markdown]
# Once we have `fit` the imputer (note that we fit all of the numeric rows at once, we don't need an imputer per column), we can then _transform_ the data.

# %%
elect_df_train.loc[:, "MalesPer100Females":"FarmArea"] = final_imputer.transform(elect_df_train.loc[:, "MalesPer100Females":"FarmArea"])

# %% [markdown]
# We can also impute on our testing data set as well using our `final_imputer`.

# %%
elect_df_test.loc[:, "MalesPer100Females":"FarmArea"] = final_imputer.transform(elect_df_test.loc[:, "MalesPer100Females":"FarmArea"])

# %% [markdown]
# Now we can build our final model following the same steps that we did above (note that if you are choosing a different model or you used different variables, this process will be slightly different).

# %%
variables_final = [variable for variable in elect_df_smaller_train.columns if variable not in ['FIPS', 'County', 'State', 'ElectionDate', 'TotalVote', 'Obama_margin', 'Obama_margin_percent', 'Obama_wins', 'Clinton', 'Obama']]

# %%
formula_final = 'Obama_margin_percent ~ ' + " + ".join(variables[:2]) +  " + standardize(" + ") + standardize(".join(variables[2:]) + ")"

# %%
y_linear_final, X_linear_final = dmatrices(formula_final, elect_df_train, return_type="dataframe")

# %%
lm_lasso = Lasso(alpha = 1, max_iter=1000000)

# %%
lm_lasso.fit(X_linear_final, y_linear_final)

# %%
X_linear_test = build_design_matrices([X_linear_final.design_info], elect_df_test, return_type="dataframe")[0]

# %% [markdown]
# Now that we have our model built and our data transformed, we can make our final predictions and save them in `bm_all_fit_pred`.

# %%
bm_all_fit_pred = lm_lasso.predict(X_linear_test)

# %%
bm_all_fit_pred.shape

# %% [markdown]
# We can see that our data is in the right shape.
